# %%
import os
import sys
sys.path.append('../../')

import pandas as pd
import xgboost as xgb
import numpy as np
import swifter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import GridSearchCV
from datetime import datetime, timedelta
from tqdm import tqdm, tqdm_notebook
from category_encoders import TargetEncoder
import core.config as conf

# %%
tqdm_notebook().pandas()
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# 0it [00:00, ?it/s]

# %% [markdown]
# ## 01. Train Data Load

# %%
## load preprocessing data (past_d)
train_df = pd.read_csv('./result/train_past_d.csv')
test_df = pd.read_csv('./result/test_past_d.csv')

# %%
path = conf.data_path

# %%
train_df = pd.read_csv(f'{path}'+'stk_hld_train.csv')

# %%
train_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
#
#    hold_d
# 0      11
# 1      80
# 2       5
# 3      22
# 4     324

# %%
cus_df = pd.read_csv(f'{path}'+'cus_info.csv')

# %%
cus_df.head()
# Out:
#                                               act_id  sex_dit_cd  \
# 0  64aae8dd71e5c0761000db9f9a6779e504e7a4aa9dc097...           1
# 1  5f7c3a8f37d9c268d06130ff0be5d32a1b9ef68c13049f...           1
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...           2
# 3  6d497facfa1ea5901b827335553331f8555fec02a8184f...           2
# 4  b727c78d2cfc246c97b677f29a034399a0c7e7873fff44...           1
#
#    cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  \
# 0               4          99               1                  2           3
# 1               6           4               4                  2           5
# 2               7           4               3                  2           5
# 3               6           4               4                  8           5
# 4               5           2               2                  2           5
#
#    tco_cus_grd_cd  tot_ivs_te_sgm_cd  mrz_btp_dit_cd
# 0               3                  6              16
# 1               2                  6               1
# 2               5                  6               9
# 3               3                  6              16
# 4               5                  5              16

# %%
iem_df = pd.read_csv(f'{path}'+'iem_info_20210902.csv')

# %%
iem_df.head()
# Out:
#     iem_cd iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  stk_dit_cd
# 0  A000020       동화약품           8                     2          99
# 1  A000080      하이트진로          14                     2           1
# 2  A000180     성창기업지주           5                     3          99
# 3  A000227    유유제약2우B           8                    99          99
# 4  A000325     노루홀딩스우           2                    99          99

# %%
L_encoder = LabelEncoder()
L_encoder.fit(iem_df["iem_krl_nm"])
# Out:
# LabelEncoder()

# %%
iem_df['iem_krl_nm'] = L_encoder.transform(iem_df["iem_krl_nm"])

# %%
train_df = pd.merge(left = train_df, right = cus_df, how='left', on='act_id')

# %%
train_df = pd.merge(train_df, iem_df, how='left', on='iem_cd')

# %% [markdown]
# ## 02. Test Data Load

# %%
test_df = pd.read_csv(f'{path}'+'stk_hld_test.csv')

# %%
test_df = pd.merge(left = test_df, right = cus_df, how='left', on='act_id')

# %%
test_df = pd.merge(test_df, iem_df, how='left', on='iem_cd')

# %%
test_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A032640  20200522
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A160600  20190823
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A234340  20200611
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A131760  20200120
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A293490  20201217
#
#    hist_d submit_id  hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  \
# 0     153  IDX00001       0           1               9           3
# 1     335  IDX00002       0           1               9           3
# 2     139  IDX00003       0           1               9           3
# 3     236  IDX00004       0           1               9           3
# 4       9  IDX00005       0           1               9           3
#
#    cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  \
# 0               2                  2           9               5
# 1               2                  2           9               5
# 2               2                  2           9               5
# 3               2                  2           9               5
# 4               2                  2           9               5
#
#    tot_ivs_te_sgm_cd  mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  \
# 0                  5               8         418           4
# 1                  5               8        2230          10
# 2                  5               8        1515          13
# 3                  5               8        2681          13
# 4                  5               8        2450          13
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd
# 0                     1           1
# 1                     3          99
# 2                     2          99
# 3                     3          99
# 4                     1           2

# %% [markdown]
# ## 03. Stock Hist

# %%
stk_df = pd.read_csv(f'{path}'+'stk_bnc_hist.csv')

# %%
stk_df.head()
# Out:
#                                               act_id    bse_dt   iem_cd  \
# 0  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200820  A008770
# 1  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200623  A008770
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20160104  A005940
# 3  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200814  A005930
# 4  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200623  A005930
#
#    bnc_qty  tot_aet_amt  stk_par_pr
# 0     40.0    2828000.0      5000.0
# 1     20.0    1390000.0      5000.0
# 2    311.0    2982490.0      5000.0
# 3     40.0    2320000.0       100.0
# 4     20.0    1028000.0       100.0

# %%
# past_d

# %%
def working_day(s_dt, e_dt) : # 공휴일 제외
    s_dt = str(s_dt).split('.')[0]
    e_dt = str(e_dt).split('.')[0]
    s_dt = s_dt[:4] + '-' + s_dt[4:6] + '-' + s_dt[6:]
    e_dt = e_dt[:4] + '-' + e_dt[4:6] + '-' + e_dt[6:]
    return np.busday_count(s_dt, e_dt, weekmask='1111100')

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Past_d

# %%
stk_df = stk_df.sort_values(by=['bse_dt'])

# %%
train_df['past_d'] = train_df.swifter.progress_bar().apply(lambda x : stk_hist(x['act_id'], x['iem_cd']), axis = 1)
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Dask Apply:   0%|          | 0/40 [00:00<?, ?it/s]
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
test_df['past_d'] = test_df.apply(lambda x : stk_hist(x['act_id'], x['iem_cd']), axis = 1)
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %% [markdown]
# #### user avg past_d : 사용자 별 past_d
# #### iem avg past_d : 종목 별 평균 past_d
# #### ivs  icn avg past_d : 투자성향 별 평균 past_d
# #### mkt_pr_tal_scl_tp_cd : 시가총액 규모 별 평균 past_d
# -> 제대로 하려면 stk_hist 파일 돌려서 다시 구해야 함

# %%
user_avg_pastd = train_df['past_d'].groupby(train_df['act_id']).mean()

# %%
iem_avg_pastd = train_df['past_d'].groupby(train_df['iem_cd']).mean()

# %%
ivs_icn_avg_pastd = train_df['past_d'].groupby(train_df['ivs_icn_cd']).mean()

# %%
user_avg_pastd_test = test_df['past_d'].groupby(test_df['act_id']).mean()

# %%
iem_avg_pastd_test = test_df['past_d'].groupby(test_df['iem_cd']).mean()

# %%
mkt_pr_avg_pastd = train_df['past_d'].groupby(train_df['mkt_pr_tal_scl_tp_cd']).mean()

# %%
train_df['user_avg_past_d'] = train_df.apply(lambda x : user_avg_pastd[x['act_id']], axis = 1)

# %%
train_df['iem_avg_past_d'] = train_df.apply(lambda x : iem_avg_pastd[x['iem_cd']], axis = 1)

# %%
train_df['ivs_icn_past_d'] = train_df.apply(lambda x : ivs_icn_avg_pastd[x['ivs_icn_cd']], axis = 1)

# %%
train_df['mkt_pr_past_d'] = train_df.apply(lambda x : mkt_pr_avg_pastd[x['mkt_pr_tal_scl_tp_cd']], axis = 1)

# %%
test_df['user_avg_past_d'] = test_df.apply(lambda x : user_avg_pastd[x['act_id']] if x['act_id'] in user_avg_pastd else user_avg_pastd_test[x['act_id']], axis = 1)

# %%
test_df['iem_avg_past_d'] = test_df.apply(lambda x : iem_avg_pastd[x['iem_cd']] if x['iem_cd'] in iem_avg_pastd else iem_avg_pastd_test[x['iem_cd']], axis = 1)

# %%
test_df['ivs_icn_past_d'] = test_df.apply(lambda x : ivs_icn_avg_pastd[x['ivs_icn_cd']], axis = 1)

# %%
test_df['mkt_pr_past_d'] = test_df.apply(lambda x : mkt_pr_avg_pastd[x['mkt_pr_tal_scl_tp_cd']], axis = 1)

# %%
train_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
#
#    hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0      11           1               9           3               2
# 1      80           1               9           3               2
# 2       5           1               9           3               2
# 3      22           1               9           3               2
# 4     324           1               9           3               2
#
#    mrz_pdt_tp_sgm_cd  lsg_sgm_cd  ...  iem_krl_nm  btp_cfc_cd  \
# 0                  2           9  ...         101           1
# 1                  2           9  ...        1361           9
# 2                  2           9  ...        2530          12
# 3                  2           9  ...        1969           8
# 4                  2           9  ...        1696          10
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd  past_d  hist_d  user_avg_past_d  \
# 0                     1           1   195.0     6.6        41.074468
# 1                     1           1    86.0    48.0        41.074468
# 2                     2          99     6.0     3.0        41.074468
# 3                     2           1    22.0    13.2        41.074468
# 4                     3          99   347.0   194.4        41.074468
#
#    iem_avg_past_d  ivs_icn_past_d  mkt_pr_past_d
# 0       66.392544       39.918768      58.505146
# 1      101.057144       39.918768      58.505146
# 2       44.857150       39.918768      40.248910
# 3       44.580025       39.918768      40.248910
# 4       81.323587       39.918768      36.059944
#
# [5 rows x 23 columns]

# %%
test_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A032640  20200522
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A160600  20190823
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A234340  20200611
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A131760  20200120
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A293490  20201217
#
#    hist_d submit_id  hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  \
# 0     153  IDX00001       0           1               9           3
# 1     335  IDX00002       0           1               9           3
# 2     139  IDX00003       0           1               9           3
# 3     236  IDX00004       0           1               9           3
# 4       9  IDX00005       0           1               9           3
#
#    cus_aet_stn_cd  ...  mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  \
# 0               2  ...               8         418           4
# 1               2  ...               8        2230          10
# 2               2  ...               8        1515          13
# 3               2  ...               8        2681          13
# 4               2  ...               8        2450          13
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd  past_d  user_avg_past_d  iem_avg_past_d  \
# 0                     1           1   159.0        41.074468       87.701799
# 1                     3          99   354.0        41.074468       33.203922
# 2                     2          99   145.0        41.074468       31.919831
# 3                     3          99   248.0        41.074468       37.868490
# 4                     1           2    10.0        41.074468       15.034166
#
#    ivs_icn_past_d  mkt_pr_past_d
# 0       39.918768      58.505146
# 1       39.918768      36.059944
# 2       39.918768      40.248910
# 3       39.918768      36.059944
# 4       39.918768      58.505146
#
# [5 rows x 24 columns]

# %% [markdown]
# #### hist d :

# %%
train_df["hist_d"] = train_df["hold_d"]*0.6

# %%
train_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
#
#    hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0      11           1               9           3               2
# 1      80           1               9           3               2
# 2       5           1               9           3               2
# 3      22           1               9           3               2
# 4     324           1               9           3               2
#
#    mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                  2           9               5                  5
# 1                  2           9               5                  5
# 2                  2           9               5                  5
# 3                  2           9               5                  5
# 4                  2           9               5                  5
#
#    mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  stk_dit_cd  \
# 0               8         101           1                     1           1
# 1               8        1361           9                     1           1
# 2               8        2530          12                     2          99
# 3               8        1969           8                     2           1
# 4               8        1696          10                     3          99
#
#    past_d  hist_d
# 0   195.0     6.6
# 1    86.0    48.0
# 2     6.0     3.0
# 3    22.0    13.2
# 4   347.0   194.4

# %%
test_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A032640  20200522
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A160600  20190823
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A234340  20200611
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A131760  20200120
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A293490  20201217
#
#    hist_d submit_id  hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  \
# 0     153  IDX00001       0           1               9           3
# 1     335  IDX00002       0           1               9           3
# 2     139  IDX00003       0           1               9           3
# 3     236  IDX00004       0           1               9           3
# 4       9  IDX00005       0           1               9           3
#
#    cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  \
# 0               2                  2           9               5
# 1               2                  2           9               5
# 2               2                  2           9               5
# 3               2                  2           9               5
# 4               2                  2           9               5
#
#    tot_ivs_te_sgm_cd  mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  \
# 0                  5               8         418           4
# 1                  5               8        2230          10
# 2                  5               8        1515          13
# 3                  5               8        2681          13
# 4                  5               8        2450          13
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd  past_d
# 0                     1           1   159.0
# 1                     3          99   354.0
# 2                     2          99   145.0
# 3                     3          99   248.0
# 4                     1           2    10.0

# %% [markdown]
# ## External Data Featuring

# %%
external_path = conf.external_path

# %%
stk_mean_df = pd.read_csv(external_path+'mean_stockdata.csv')

# %%
stk_mean_df['code'] = stk_mean_df.apply(lambda x : 'A' + x['code'], axis = 1)

# %%
stk_mean_df
# Out:
#          code          oepn          high           low         close  \
# 0     A000020  10628.321108  10875.158924  10395.338223  10611.340668
# 1     A000080  13718.842105  13873.710526  13566.907895  14156.565789
# 2     A000180   3205.013040   3268.528117   3137.779136   3229.211084
# 3     A000227  13186.233089  13408.596577  12970.257539  13402.982885
# 4     A000325  18285.819071  18510.423798  18045.867971  18283.928280
# ...       ...           ...           ...           ...           ...
# 2807  A156080  10585.937500  10747.812500  10474.375000  10595.937500
# 2808  A160980  10113.500000  10179.500000   9927.500000  10037.000000
# 2809  A161580  10127.000000  10232.000000   9951.000000  10080.000000
# 2810  A163730  10156.500000  10307.250000  10123.000000  10264.500000
# 2811  A168330  10015.500000  10039.000000   9937.000000   9957.500000
#
#             volume     chage
# 0     4.514417e+05  0.001178
# 1     1.592198e+06  0.000800
# 2     1.243295e+06 -0.000945
# 3     3.864996e+04 -0.000098
# 4     1.757751e+05  0.000082
# ...            ...       ...
# 2807  2.414732e+05  0.007861
# 2808  1.963900e+04  0.000063
# 2809  8.949426e+05  0.001339
# 2810  9.705650e+04  0.016875
# 2811  6.615750e+03 -0.001647
#
# [2812 rows x 7 columns]

# %%
train_df = pd.merge(left = train_df, right = stk_mean_df[['code', 'volume']], how='left', left_on='iem_cd', right_on = 'code')

# %%
test_df = pd.merge(left = test_df, right = stk_mean_df[['code', 'volume']], how='left', left_on='iem_cd', right_on = 'code')

# %% [markdown]
# ## Target Encoding

# %%
target_encoder = TargetEncoder()

# %%
target_encoder.fit(train_df['iem_cd'], train_df['hold_d'])
# Out:
# TargetEncoder(cols=['iem_cd'])

# %%
train_df['iem_cd_te'] = target_encoder.transform(train_df['iem_cd'], train_df['hold_d'])

# %%
test_df['iem_cd_te'] = target_encoder.transform(test_df['iem_cd'], test_df['hold_d'])

# %%
test_df = test_df.fillna(0)

# %%
train_df = train_df.fillna(0)

# %%
#target_encoder.transform(train_df['ivs_icn_cd'], train_df['hold_d'])

# %% [markdown]
# ## past_d 계산

# %%
id_stk_dur_df = pd.read_csv(conf.data_path + 'id_stk_dur_list.csv')

# %%
train_df = pd.merge(train_df, id_stk_dur_df[['act_id', 'iem_cd', 'mean']], how = 'left', on = ['act_id', 'iem_cd'])

# %%
test_df = pd.merge(test_df, id_stk_dur_df[['act_id', 'iem_cd', 'mean']], how = 'left', on = ['act_id', 'iem_cd'])

# %% [markdown]
# ## Drop Features

# %%
train_df = train_df.drop(['act_id', 'iem_cd', 'code', 'byn_dt', 'past_d'], axis = 1)

# %%
used_features = train_df.columns.drop('hold_d')

# %%
test_df = test_df[used_features]

# %%
train_df.columns
# Out:
# Index(['hold_d', 'sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd',
#        'cus_aet_stn_cd', 'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'hist_d', 'volume', 'iem_cd_te',
#        'mean'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd', 'cus_aet_stn_cd',
#        'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'hist_d', 'volume', 'iem_cd_te',
#        'mean'],
#       dtype='object')

# %% [markdown]
# ## 03. XGBoost

# %%
col = train_df.columns

# %%
col = col.drop('hold_d')

# %%
TARGET = 'hold_d'

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_df[col], train_df[TARGET], test_size = 0.2)

# %%
model = xgb.XGBRegressor(n_estimators=1000, max_depth=8, min_child_weighteta=0.1, subsample=0.7, colsample_bytree=0.8)

# %% [markdown]
# #### GridSearch

# %%
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'eta' :[0.05, 0.1],
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7, 8],
              'min_child_weight': [1, 2, 4, 6],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500, 1000]}

xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

# %%
model.fit(X_train, y_train, verbose=False)
# Out:
# [20:07:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#              min_child_weight=1, min_child_weighteta=0.1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=20,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=0.7, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_grid.fit(X_train, y_train, verbose=False)
# Out:
# Fitting 2 folds for each of 192 candidates, totalling 384 fits
# [12:36:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:36:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:37:01] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:01] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:37:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:39:44] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:39:44] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:40:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:40:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:00] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:00] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:42:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:42:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:43:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:43:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:44:25] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:25] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:45:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:45:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [12:36:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:36:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:37:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:39:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:39:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:40:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:40:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:01] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:01] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:47] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:47] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:42:33] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:42:33] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:44:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:45:34] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:45:34] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:46:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:46:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:36:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:37:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:37:33] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:33] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:39:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:39:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:40:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:40:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:49] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:49] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:42:34] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:42:34] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:43:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:43:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:44:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:46:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:46:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:47:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:51] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:51] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:53] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:49:53] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:36:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:37:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:39:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:39:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:39:58] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:39:58] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:42:43] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:42:43] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:43:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:43:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:44:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:45:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:45:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:46:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:46:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:25] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:47:25] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:15] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:15] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:54] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:49:54] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:52:45] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:52:45] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:36:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:36:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:37:34] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:34] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:38:34] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:34] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:39:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:39:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:41:47] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:47] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:43:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:43:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:44:45] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:45] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:45:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:45:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:23] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:47:23] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:49:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:05] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:05] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:36] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:36] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:52:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:52:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:25] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:53:25] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:54:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:54:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:47:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:47:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:49:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:43] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:49:43] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:56] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:56] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:53:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:54:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:54:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:55:17] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:55:17] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:56:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:56:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:57:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:57:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:57:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:58:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:58:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:01:00] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:01:00] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:02:51] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:02:51] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:03:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:03:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:04:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:04:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:48:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:49:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:49] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:49] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:52:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [12:52:37] WARNING: ../src/learner.cc:573:
# ...
#
#
# [13:39:13] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:39:13] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:40:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:40:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:40:56] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:40:56] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:42:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:42:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:44:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:44:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:45:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:45:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:47:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:47:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:49:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:49:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:50:51] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:50:51] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:51:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:51:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:52:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:52:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:52:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:52:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:36:52] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:36:52] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:38:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:38:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:39:05] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:39:05] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:40:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:40:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:42:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:42:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:43:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:43:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:44:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:44:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:46:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:46:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:47:49] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:47:49] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:49:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:49:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:50:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:50:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:51:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:51:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:53:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:53:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:53:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:53:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:39] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:54:39] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:55:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [14:04:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:04:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=2,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None, colsample_bytree=0.8,
#                                     gamma=None, gpu_id=None,
#                                     importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=8, min_child_weight=None,
#                                     min_child_weighteta=0.1, missing=nan,
#                                     monotone_constraints=None,
#                                     n_es...
#                                     scale_pos_weight=None, subsample=0.7,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              n_jobs=5,
#              param_grid={'colsample_bytree': [0.7], 'eta': [0.05, 0.1],
#                          'learning_rate': [0.03, 0.05, 0.07],
#                          'max_depth': [5, 6, 7, 8],
#                          'min_child_weight': [1, 2, 4, 6],
#                          'n_estimators': [500, 1000], 'nthread': [4],
#                          'objective': ['reg:linear'], 'silent': [1],
#                          'subsample': [0.7]},
#              verbose=True)

# %%
import joblib

# %%
joblib.dump(xgb_grid, 'xgb_gridcv.pkl')
# Out:
# ['xgb_gridcv.pkl']
# [21:23:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:23:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:24:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:24:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:26:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:26:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:27:15] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:27:15] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:28:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:28:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:28:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:28:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:29:47] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:29:47] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:30:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:30:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:31:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:32:39] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:32:39] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:33:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:33:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:35:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:36:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:37:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:38:54] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:54] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:40:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [21:23:53] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:23:53] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:25:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:25:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:27:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:27:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:28:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:28:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:29:44] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:29:44] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:30:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:30:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:31:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:32:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:32:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:33:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:34:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:35:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:36:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:37:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:38:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:40:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [21:26:01] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:26:01] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:27:47] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:27:47] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:29:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:29:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:30:34] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:30:34] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:31:05] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:05] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:31:43] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:43] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:32:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:32:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:33:45] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:45] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:34:58] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:58] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:35:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:37:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:38:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:39:33] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:33] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:40:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [21:29:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:29:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:30:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:30:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:30:54] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:30:54] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:31:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:33:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:33:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:34:44] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:44] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:36:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:37:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:38:36] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:36] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:39:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:41:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [21:41:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
xgb.plot_importance(model)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_77243/4261653415.py in <module>
# ----> 1 xgb.plot_importance(model)
#
# ~/anaconda3/envs/nh2021/lib/python3.7/site-packages/xgboost/plotting.py in plot_importance(booster, ax, height, xlim, ylim, title, xlabel, ylabel, fmap, importance_type, max_num_features, grid, show_values, **kwargs)
#      61
#      62     if isinstance(booster, XGBModel):
# ---> 63         importance = booster.get_booster().get_score(
#      64             importance_type=importance_type, fmap=fmap)
#      65     elif isinstance(booster, Booster):
#
# ~/anaconda3/envs/nh2021/lib/python3.7/site-packages/xgboost/sklearn.py in get_booster(self)
#     395         if not hasattr(self, '_Booster'):
#     396             from sklearn.exceptions import NotFittedError
# --> 397             raise NotFittedError('need to call fit or load_model beforehand')
#     398         return self._Booster
#     399
#
# NotFittedError: need to call fit or load_model beforehand

# %%
xgb_grid.score(X_train, y_train)
# Out:
# 0.9999891255029099

# %%
model.score(X_train, y_train)
# Out:
# 0.9999867422859888

# %% [markdown]
# ## Predict Score

# %%
pred = model.predict(X_valid)

# %%
pred = xgb_grid.predict(X_valid)

# %%
y_valid.values
# Out:
# array([ 1,  1, 28, ...,  4, 11, 19])

# %%
np.round(pred)
# Out:
# array([ 1.,  1., 28., ...,  4., 11., 19.], dtype=float32)

# %%
np.sqrt(mean_squared_error(y_valid.values, np.round(pred)))
# Out:
# 0.2309231629177619

# %% [markdown]
# ## 04. Submission

# %%
submission = pd.read_csv(f"{path}"+"sample_submission.csv")

# %%
y_pred = xgb_grid.predict(test_df)

# %%
y_pred = model.predict(test_df)

# %%
y_pred
# Out:
# array([ 255.3505   ,  555.616    ,  232.19318  , ..., 1041.981    ,
#          18.004068 ,    7.0241246], dtype=float32)

# %%
result = []
for i in y_pred:
    result.append(i)

# %%
result
# Out:
# [255.3505,
#  555.616,
#  232.19318,
#  393.02863,
#  14.885926,
#  154.54553,
#  167.63611,
#  1042.3467,
#  135.35214,
#  841.32184,
#  201.5839,
#  1164.6857,
#  749.91064,
#  10.079292,
#  18.046349,
#  5.06686,
#  187.89557,
#  117.43706,
#  469.3259,
#  13.039008,
#  10.044616,
#  1155.4307,
#  693.1723,
#  27.056496,
#  3.1005492,
#  111.89685,
#  111.93448,
#  393.0884,
#  752.306,
#  468.92624,
#  114.99458,
#  115.11899,
#  1036.2914,
#  218.34941,
#  20.051285,
#  128.28542,
#  218.40517,
#  1149.0049,
#  218.4102,
#  1114.8121,
#  1172.3646,
#  716.7076,
#  1154.1947,
#  1169.2665,
#  1119.3865,
#  1012.66705,
#  1121.8529,
#  1178.7136,
#  1169.2109,
#  1171.6953,
#  1165.0485,
#  1119.4199,
#  233.41718,
#  1006.9923,
#  1011.9559,
#  242.47157,
#  217.60568,
#  993.34106,
#  1001.89404,
#  1031.3984,
#  122.81199,
#  1014.83636,
#  964.8978,
#  1032.8284,
#  932.85126,
#  980.8714,
#  1012.96075,
#  122.65766,
#  201.60352,
#  963.7537,
#  1001.68427,
#  997.8182,
#  1005.80096,
#  1151.5768,
#  20.03546,
#  250.40309,
#  43.041367,
#  39.96264,
#  245.55884,
#  18.031649,
#  1.9789472,
#  1098.1925,
#  1163.6685,
#  1060.4639,
#  11.986095,
#  298.48923,
#  235.741,
#  38.073055,
#  17.016943,
#  8.047193,
#  2.0171118,
#  361.38522,
#  39.948692,
#  19.99917,
#  2.0488286,
#  15.062719,
#  13.007665,
#  3.0742834,
#  36.943283,
#  171.8718,
#  8.388728,
#  12.956752,
#  62.997845,
#  749.23865,
#  33.076508,
#  154.65652,
#  1.9849478,
#  2.9748473,
#  158.23004,
#  97.24239,
#  478.62915,
#  167.78708,
#  117.9191,
#  7.931182,
#  390.2956,
#  24.989723,
#  20.056164,
#  3.1036816,
#  7.0958557,
#  160.30653,
#  2.0351868,
#  117.94663,
#  395.91696,
#  81.98739,
#  751.54065,
#  982.56433,
#  399.7757,
#  477.63116,
#  988.39,
#  2.100034,
#  1016.6994,
#  46.82669,
#  261.47263,
#  968.9959,
#  156.76978,
#  12.011832,
#  176.86752,
#  968.9642,
#  976.8959,
#  264.11612,
#  177.24355,
#  17.032455,
#  161.86877,
#  12.042662,
#  226.4376,
#  42.10594,
#  139.9972,
#  62.9454,
#  137.09863,
#  62.12473,
#  12.954207,
#  1158.8721,
#  1177.0178,
#  1176.0751,
#  1163.1503,
#  1177.3394,
#  649.13446,
#  967.5218,
#  154.8107,
#  7.960124,
#  59.965767,
#  236.72256,
#  2.0155666,
#  4.901501,
#  1046.4923,
#  12.942591,
#  27.015892,
#  19.986753,
#  4.9622436,
#  1.9602957,
#  6.9616427,
#  6.941722,
#  6.9815474,
#  339.74048,
#  1148.1204,
#  1018.3992,
#  2.7852142,
#  17.131926,
#  50.54074,
#  9.98398,
#  10.08582,
#  28.173914,
#  10.027294,
#  202.93094,
#  981.5932,
#  701.38135,
#  12.0384445,
#  19.972542,
#  32.88497,
#  41.976864,
#  11.967105,
#  15.080495,
#  27.92421,
#  24.831146,
#  52.60978,
#  30.541779,
#  102.71559,
#  356.43674,
#  1094.2188,
#  99.70365,
#  130.33856,
#  13.069563,
#  16.805592,
#  60.209415,
#  139.7512,
#  168.49155,
#  142.18692,
#  1116.0398,
#  99.95368,
#  78.14292,
#  142.1856,
#  192.67241,
#  52.16987,
#  68.32957,
#  132.1894,
#  124.82708,
#  91.60205,
#  139.94847,
#  98.19761,
#  8.068334,
#  964.798,
#  93.25865,
#  1.9347264,
#  32.030895,
#  59.986656,
#  5.0060215,
#  4.9601283,
#  1005.55,
#  178.61188,
#  395.8229,
#  46.979935,
#  1023.5906,
#  298.73056,
#  95.33748,
#  133.48172,
#  700.0244,
#  35.109882,
#  148.1657,
#  133.17145,
#  124.97756,
#  711.132,
#  750.56366,
#  243.03839,
#  97.97151,
#  209.66821,
#  102.67913,
#  168.43248,
#  95.13035,
#  74.936844,
#  60.123802,
#  204.91037,
#  59.9315,
#  31.964935,
#  11.905176,
#  4.9604626,
#  152.90479,
#  20.08701,
#  15.020358,
#  1035.7031,
#  650.3521,
#  243.00717,
#  10.0476,
#  1160.9022,
#  205.7381,
#  13.075608,
#  974.75134,
#  92.04682,
#  20.142536,
#  117.208534,
#  128.06519,
#  995.97217,
#  1161.3313,
#  1160.3165,
#  1017.95856,
#  1018.16785,
#  1046.1978,
#  1157.0602,
#  889.01154,
#  1002.11615,
#  1154.7363,
#  1025.7886,
#  1155.9906,
#  16.98226,
#  26.879421,
#  2.9021904,
#  14.90161,
#  24.935051,
#  392.62643,
#  9.916245,
#  52.944897,
#  11.863615,
#  39.947685,
#  32.94782,
#  1.9128406,
#  17.871675,
#  31.940943,
#  24.829273,
#  6.890362,
#  950.1678,
#  58.158443,
#  7.064319,
#  8.0308695,
#  1.9444445,
#  62.14447,
#  37.108147,
#  107.66142,
#  52.16027,
#  45.14216,
#  62.09247,
#  37.13229,
#  2.1238675,
#  124.958664,
#  60.23886,
#  225.88857,
#  45.103836,
#  463.1323,
#  210.43254,
#  210.12029,
#  226.5429,
#  345.17422,
#  33.158142,
#  222.68105,
#  207.54347,
#  10.135743,
#  8.13963,
#  27.143402,
#  70.59864,
#  352.11423,
#  207.51204,
#  52.153862,
#  173.44792,
#  315.95956,
#  8.060442,
#  182.98602,
#  60.270653,
#  43.123306,
#  121.88095,
#  163.69788,
#  242.94995,
#  183.14703,
#  191.21634,
#  170.39185,
#  227.71584,
#  120.39781,
#  56.923363,
#  58.20583,
#  30.109064,
#  226.26021,
#  167.80179,
#  396.3493,
#  45.14489,
#  35.2957,
#  177.45174,
#  35.238045,
#  86.95023,
#  180.1706,
#  37.12783,
#  26.935083,
#  37.120407,
#  53.09637,
#  224.09697,
#  226.2198,
#  56.848217,
#  252.35658,
#  163.29324,
#  189.75159,
#  243.00728,
#  153.15619,
#  163.24367,
#  207.64119,
#  142.20636,
#  48.132027,
#  142.20204,
#  345.2428,
#  108.15505,
#  487.7866,
#  142.21327,
#  243.00867,
#  185.44281,
#  207.46762,
#  118.03112,
#  170.4252,
#  170.36824,
#  108.1656,
#  226.02383,
#  17.093555,
#  227.51805,
#  83.09821,
#  45.102715,
#  153.12538,
#  183.00356,
#  207.47862,
#  145.76602,
#  142.17111,
#  37.119644,
#  226.1213,
#  222.389,
#  45.14288,
#  43.14811,
#  120.82455,
#  349.02322,
#  226.02354,
#  132.22891,
#  45.147167,
#  398.96857,
#  20.183094,
#  58.125843,
#  10.188361,
#  361.80295,
#  128.11996,
#  130.47232,
#  640.9192,
#  212.39967,
#  940.7138,
#  977.6936,
#  273.10693,
#  121.91597,
#  931.9465,
#  21.98387,
#  974.60156,
#  12.938412,
#  568.63605,
#  118.10006,
#  132.35008,
#  285.19385,
#  1022.3529,
#  17.132046,
#  1006.00555,
#  130.57024,
#  123.01284,
#  39.916798,
#  270.52045,
#  115.13425,
#  2.9809341,
#  22.092535,
#  128.09615,
#  123.011406,
#  992.8761,
#  112.629616,
#  165.16716,
#  801.7671,
#  167.21184,
#  383.51544,
#  170.40906,
#  167.46333,
#  812.37744,
#  1112.1165,
#  1172.6982,
#  1166.386,
#  1174.7754,
#  138.10709,
#  1049.5103,
#  960.3057,
#  6.664631,
#  232.94466,
#  72.61762,
#  11.940502,
#  58.10866,
#  118.06911,
#  109.80378,
#  12.902199,
#  724.8095,
#  481.4538,
#  10.004677,
#  2.0251517,
#  7.991697,
#  242.01558,
#  188.19028,
#  212.27336,
#  7.0931845,
#  255.33542,
#  118.155945,
#  257.9154,
#  22.077415,
#  128.22105,
#  209.35301,
#  95.310394,
#  13.248897,
#  133.46521,
#  109.96086,
#  215.28075,
#  117.02363,
#  215.8072,
#  274.6882,
#  158.59488,
#  212.35735,
#  283.16028,
#  154.76367,
#  54.901077,
#  1157.4995,
#  128.28026,
#  257.92154,
#  28.03023,
#  218.0388,
#  273.3118,
#  1155.2186,
#  318.3084,
#  2.0550818,
#  6.909716,
#  7.1003265,
#  6.9875727,
#  133.27644,
#  28.108418,
#  5.0385723,
#  15.019451,
#  1169.4447,
#  1157.7249,
#  71.82379,
#  1166.3861,
#  42.016937,
#  26.985712,
#  127.9084,
#  190.0795,
#  25.006092,
#  108.01218,
#  59.959908,
#  42.96318,
#  44.820324,
#  16.953753,
#  122.9003,
#  62.319145,
#  48.02888,
#  56.829082,
#  65.043755,
#  22.980333,
#  37.06811,
#  80.14986,
#  14.981352,
#  17.947224,
#  6.964635,
#  74.97478,
#  76.83367,
#  99.972626,
#  76.646736,
#  14.985922,
#  41.999157,
#  9.96131,
#  93.016525,
#  89.79865,
#  1002.1021,
#  133.17517,
#  11.997901,
#  543.81256,
#  68.0488,
#  17.948132,
#  24.897923,
#  187.37915,
#  55.093887,
#  2.0074823,
#  743.5911,
#  14.97498,
#  44.968735,
#  4.934949,
#  27.943745,
#  9.977748,
#  52.00245,
#  246.36015,
#  81.91792,
#  1.9207811,
#  87.836876,
#  76.93882,
#  36.89217,
#  5.0176573,
#  11.907706,
#  36.628746,
#  1002.074,
#  70.15095,
#  373.83176,
#  270.4463,
#  293.22775,
#  63.350517,
#  307.27206,
#  370.18146,
#  175.16365,
#  370.62802,
#  7.1547737,
#  122.12541,
#  2.3765519,
#  2.1559284,
#  5.161842,
#  7.1823964,
#  2.1457486,
#  88.06612,
#  63.004135,
#  1018.9254,
#  52.96814,
#  983.14575,
#  1049.3455,
#  42.00184,
#  41.948483,
#  986.7325,
#  30.013279,
#  71.99788,
#  35.06885,
#  65.10792,
#  746.92224,
#  38.073193,
#  167.74411,
#  9.924696,
#  31.926378,
#  16.952904,
#  1160.9392,
#  15.12578,
#  8.0457945,
#  2.02114,
#  977.0713,
#  1.9491444,
#  1.98226,
#  21.93079,
#  14.944825,
#  1086.7771,
#  1076.9895,
#  1015.4806,
#  983.3279,
#  1085.929,
#  143.26039,
#  22.113764,
#  20.084478,
#  259.39487,
#  859.2688,
#  453.06744,
#  847.9385,
#  1166.7346,
#  453.08725,
#  9.935646,
#  136.94995,
#  130.25217,
#  7.0117135,
#  614.11786,
#  700.48065,
#  1.9477471,
#  10.113036,
#  64.9266,
#  7.055747,
#  43.02384,
#  32.087864,
#  8.050368,
#  341.68726,
#  28.101923,
#  13.081232,
#  11.965614,
#  1.9568007,
#  60.12088,
#  314.3333,
#  17.847622,
#  698.51746,
#  179.9646,
#  47.725033,
#  1032.3085,
#  9.893287,
#  365.97937,
#  47.708282,
#  304.932,
#  101.833435,
#  2.9497707,
#  47.01944,
#  12.973435,
#  11.977061,
#  263.33994,
#  32.862576,
#  7.9230886,
#  14.866995,
#  2.9885035,
#  711.4962,
#  746.2455,
#  29.940681,
#  2.9964218,
#  4.969168,
#  7.9501457,
#  27.980843,
#  17.010942,
#  103.25319,
#  2.894824,
#  137.73456,
#  139.84872,
#  713.70605,
#  717.44775,
#  1035.5874,
#  139.75418,
#  8.171496,
#  2.9119043,
#  11.976734,
#  245.65547,
#  972.47784,
#  638.0456,
#  52.99887,
#  150.7999,
#  111.94224,
#  37.916737,
#  16.889156,
#  37.96378,
#  1007.36414,
#  12.169422,
#  215.35297,
#  12.1226635,
#  296.6086,
#  297.03494,
#  127.21576,
#  175.1637,
#  178.63004,
#  296.84332,
#  161.80203,
#  22.527658,
#  43.092552,
#  201.85475,
#  1046.9321,
#  1044.4434,
#  673.3037,
#  631.2905,
#  716.55786,
#  940.8511,
#  1042.6367,
#  529.0613,
#  663.3735,
#  631.3929,
#  1002.8213,
#  521.1048,
#  898.8599,
#  1121.0793,
#  1023.6002,
#  1050.7249,
#  946.90796,
#  1086.049,
#  628.90546,
#  759.61694,
#  387.6863,
#  760.6043,
#  1052.1317,
#  1031.2429,
#  43.142445,
#  143.24294,
#  1022.37634,
#  168.35301,
#  16.954205,
#  4.977084,
#  411.09976,
#  89.93161,
#  238.7345,
#  943.55493,
#  11.872413,
#  22.88864,
#  4.9532647,
#  237.29855,
#  224.60779,
#  224.82027,
#  490.87708,
#  1050.918,
#  64.26784,
#  987.88354,
#  47.426464,
#  381.73126,
#  122.247116,
#  7.623226,
#  148.00636,
#  301.30573,
#  58.750507,
#  115.022385,
#  91.84021,
#  4.926353,
#  1.9745578,
#  1.9637986,
#  121.73679,
#  238.4234,
#  274.46307,
#  1013.51324,
#  1078.4915,
#  1035.495,
#  335.28366,
#  324.89975,
#  1074.6816,
#  1047.5326,
#  1076.4572,
#  1074.0435,
#  510.59872,
#  507.62326,
#  1036.6869,
#  1007.24963,
#  1034.1674,
#  380.72064,
#  1039.9802,
#  855.0131,
#  28.154222,
#  15.147099,
#  20.138395,
#  7.120371,
#  8.067876,
#  80.305016,
#  374.26935,
#  317.81805,
#  13.087573,
#  28.120935,
#  42.21045,
#  120.45423,
#  53.12166,
#  50.139004,
#  27.115023,
#  5.059773,
#  262.54987,
#  105.03693,
#  40.345707,
#  30.116716,
#  121.774,
#  138.1805,
#  17.066137,
#  80.12675,
#  180.19662,
#  383.49814,
#  9.993215,
#  12.917894,
#  17.001816,
#  135.93088,
#  1015.5282,
#  741.60895,
#  388.5858,
#  216.4448,
#  484.90976,
#  214.06767,
#  192.81552,
#  9.962813,
#  1.968617,
#  9.980161,
#  56.831417,
#  37.118347,
#  38.00863,
#  15.021887,
#  267.2263,
#  6.9880543,
#  9.952033,
#  44.962597,
#  42.18887,
#  141.72366,
#  2.9467196,
#  2.9713159,
#  146.58435,
#  43.071068,
#  3.0586503,
#  9.972339,
#  994.8745,
#  10.057898,
#  17.044144,
#  22.207449,
#  2.0039992,
#  103.185875,
#  8.076085,
#  2.9957657,
#  3.0221624,
#  1.9391534,
#  15.05968,
#  68.020004,
#  51.90709,
#  7.0815988,
#  138.21487,
#  15.105492,
#  99.903625,
#  279.58957,
#  513.87115,
#  44.96219,
#  15.081417,
#  10.141571,
#  17.132685,
#  28.060194,
#  18.118336,
#  25.131203,
#  97.79426,
#  497.14896,
#  977.3244,
#  351.87717,
#  497.7529,
#  1094.5251,
#  116.636185,
#  1.9165471,
#  852.1462,
#  6.893835,
#  102.93719,
#  47.025784,
#  662.58105,
#  21.931334,
#  1036.9305,
#  1037.1929,
#  1053.0251,
#  1044.3563,
#  1043.8049,
#  243.63618,
#  27.949062,
#  421.53595,
#  557.98395,
#  667.42755,
#  481.74707,
#  26.953175,
#  2.9590793,
#  23.016605,
#  1.8930411,
#  35.038525,
#  52.97623,
#  29.942972,
#  44.799088,
#  19.980255,
#  16.973406,
#  56.663116,
#  84.831924,
#  37.95418,
#  47.87348,
#  39.864178,
#  16.911198,
#  81.769775,
#  1.924992,
#  41.784298,
#  16.979336,
#  49.993584,
#  16.965347,
#  19.983927,
#  9.970505,
#  3.0393481,
#  32.90482,
#  47.05399,
#  11.992845,
#  36.916058,
#  12.995673,
#  15.006163,
#  15.074902,
#  12.044105,
#  1.9722326,
#  37.01961,
#  32.947617,
#  1050.0619,
#  1079.7628,
#  1042.9476,
#  1045.7783,
#  1022.6755,
#  405.02927,
#  1051.8799,
#  1040.3135,
#  139.89658,
#  1092.0825,
#  383.34113,
#  165.32066,
#  160.30928,
#  95.19743,
#  154.62914,
#  91.82066,
#  222.86787,
#  260.68167,
#  159.20378,
#  239.40286,
#  261.03558,
#  54.29168,
#  240.25534,
#  89.902695,
#  103.16383,
#  2.991873,
#  30.073938,
#  32.354473,
#  1033.6686,
#  32.265667,
#  32.07189,
#  1015.243,
#  43.09742,
#  6.9796667,
#  54.892056,
#  43.088493,
#  7.082474,
#  11.98785,
#  82.93992,
#  16.958551,
#  158.50444,
#  225.87245,
#  31.968597,
#  46.78381,
#  19.990896,
#  12.877267,
#  265.50107,
#  21.985891,
#  89.97516,
#  42.044704,
#  42.049217,
#  29.950678,
#  120.27182,
#  127.0002,
#  30.009956,
#  2.962814,
#  92.98514,
#  216.65701,
#  165.3427,
#  212.85251,
#  44.852196,
#  37.876884,
#  29.868132,
#  361.30984,
#  193.58067,
#  10.053285,
#  99.82129,
#  52.00282,
#  218.33557,
#  20.080753,
#  31.881348,
#  31.939087,
#  35.03471,
#  20.01304,
#  35.041904,
#  317.0893,
#  ...]

# %%
submission["hold_d"] = np.round(result)

# %%
submission
# Out:
#       submit_id  hold_d
# 0      IDX00001   255.0
# 1      IDX00002   556.0
# 2      IDX00003   232.0
# 3      IDX00004   393.0
# 4      IDX00005    15.0
# ...         ...     ...
# 70591  IDX70592    38.0
# 70592  IDX70593   173.0
# 70593  IDX70594  1042.0
# 70594  IDX70595    18.0
# 70595  IDX70596     7.0
#
# [70596 rows x 2 columns]

# %%
submission.to_csv("./result/gridcv_xgboost(iem_cd_target_encoding lib with hist_d volume past_d(mean)).csv", index = False)
# Out:
# [13:53:36] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:53:36] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:54:58] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:51] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:55:51] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:33] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:33] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:02:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:02:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [13:51:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:51:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:52:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:52:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:53:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:53:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:54:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:54] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:55:54] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:39] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:39] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [13:50:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:50:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:51:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:51:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:52:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:52:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:53:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:53:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:54:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:00:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:00:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:02:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:02:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:49:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:49:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:50:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:50:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:52:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:52:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:52:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:52:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:54:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:54:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:55:43] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:55:43] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:56:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:23] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:23] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:00:01] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:00:01] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:01] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:01] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:03:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:03:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [14:00:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:00:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:02:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:02:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:03:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:03:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
