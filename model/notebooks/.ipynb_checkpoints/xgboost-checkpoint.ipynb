# %%
import os
import sys
sys.path.append('../../')

import pandas as pd
import xgboost as xgb
import numpy as np
import swifter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import GridSearchCV
from datetime import datetime, timedelta
from tqdm import tqdm, tqdm_notebook
from category_encoders import TargetEncoder
import core.config as conf

# %%
tqdm_notebook().pandas()
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# 0it [00:00, ?it/s]

# %% [markdown]
# ## 01. Train Data Load

# %%
## load preprocessing data (past_d)
train_df = pd.read_csv('./result/train_past_d.csv')
test_df = pd.read_csv('./result/test_past_d.csv')

# %%
path = conf.data_path

# %%
train_df = pd.read_csv(f'{path}'+'stk_hld_train.csv')

# %%
train_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
#
#    hold_d
# 0      11
# 1      80
# 2       5
# 3      22
# 4     324

# %%
cus_df = pd.read_csv(f'{path}'+'cus_info.csv')

# %%
cus_df.head()
# Out:
#                                               act_id  sex_dit_cd  \
# 0  64aae8dd71e5c0761000db9f9a6779e504e7a4aa9dc097...           1
# 1  5f7c3a8f37d9c268d06130ff0be5d32a1b9ef68c13049f...           1
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...           2
# 3  6d497facfa1ea5901b827335553331f8555fec02a8184f...           2
# 4  b727c78d2cfc246c97b677f29a034399a0c7e7873fff44...           1
#
#    cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  \
# 0               4          99               1                  2           3
# 1               6           4               4                  2           5
# 2               7           4               3                  2           5
# 3               6           4               4                  8           5
# 4               5           2               2                  2           5
#
#    tco_cus_grd_cd  tot_ivs_te_sgm_cd  mrz_btp_dit_cd
# 0               3                  6              16
# 1               2                  6               1
# 2               5                  6               9
# 3               3                  6              16
# 4               5                  5              16

# %%
iem_df = pd.read_csv(f'{path}'+'iem_info_20210902.csv')

# %%
iem_df.head()
# Out:
#     iem_cd iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  stk_dit_cd
# 0  A000020       동화약품           8                     2          99
# 1  A000080      하이트진로          14                     2           1
# 2  A000180     성창기업지주           5                     3          99
# 3  A000227    유유제약2우B           8                    99          99
# 4  A000325     노루홀딩스우           2                    99          99

# %%
L_encoder = LabelEncoder()
L_encoder.fit(iem_df["iem_krl_nm"])
# Out:
# LabelEncoder()

# %%
iem_df['iem_krl_nm'] = L_encoder.transform(iem_df["iem_krl_nm"])

# %%
train_df = pd.merge(left = train_df, right = cus_df, how='left', on='act_id')

# %%
train_df = pd.merge(train_df, iem_df, how='left', on='iem_cd')

# %% [markdown]
# ## 02. Test Data Load

# %%
test_df = pd.read_csv(f'{path}'+'stk_hld_test.csv')

# %%
test_df = pd.merge(left = test_df, right = cus_df, how='left', on='act_id')

# %%
test_df = pd.merge(test_df, iem_df, how='left', on='iem_cd')

# %%
test_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A032640  20200522
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A160600  20190823
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A234340  20200611
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A131760  20200120
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A293490  20201217
#
#    hist_d submit_id  hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  \
# 0     153  IDX00001       0           1               9           3
# 1     335  IDX00002       0           1               9           3
# 2     139  IDX00003       0           1               9           3
# 3     236  IDX00004       0           1               9           3
# 4       9  IDX00005       0           1               9           3
#
#    cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  \
# 0               2                  2           9               5
# 1               2                  2           9               5
# 2               2                  2           9               5
# 3               2                  2           9               5
# 4               2                  2           9               5
#
#    tot_ivs_te_sgm_cd  mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  \
# 0                  5               8         418           4
# 1                  5               8        2230          10
# 2                  5               8        1515          13
# 3                  5               8        2681          13
# 4                  5               8        2450          13
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd
# 0                     1           1
# 1                     3          99
# 2                     2          99
# 3                     3          99
# 4                     1           2

# %% [markdown]
# ## 03. Stock Hist

# %%
stk_df = pd.read_csv(f'{path}'+'stk_bnc_hist.csv')

# %%
stk_df.head()
# Out:
#                                               act_id    bse_dt   iem_cd  \
# 0  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200820  A008770
# 1  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200623  A008770
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20160104  A005940
# 3  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200814  A005930
# 4  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200623  A005930
#
#    bnc_qty  tot_aet_amt  stk_par_pr
# 0     40.0    2828000.0      5000.0
# 1     20.0    1390000.0      5000.0
# 2    311.0    2982490.0      5000.0
# 3     40.0    2320000.0       100.0
# 4     20.0    1028000.0       100.0

# %%
# past_d

# %%
def working_day(s_dt, e_dt) : # 공휴일 제외
    s_dt = str(s_dt).split('.')[0]
    e_dt = str(e_dt).split('.')[0]
    s_dt = s_dt[:4] + '-' + s_dt[4:6] + '-' + s_dt[6:]
    e_dt = e_dt[:4] + '-' + e_dt[4:6] + '-' + e_dt[6:]
    return np.busday_count(s_dt, e_dt, weekmask='1111100')

# %%
def stk_hist(act_id, iem_cd) :
    diff_date = []
    s_dt = 0
    tmp_df = stk_df[stk_df['act_id']==act_id][stk_df['iem_cd']==iem_cd][['bse_dt', 'bnc_qty']]
    if len(tmp_df) == 0 : return None

    sell = tmp_df[tmp_df['bnc_qty']==0.0]#매도
    trade = tmp_df[tmp_df['bnc_qty']!=0.0]#매매
    
    if len(sell) == 0 : # 판 기록이 없을 때
        t_dt = trade['bse_dt'].values[0]
        diff_date.append(working_day(t_dt, 20201231))
    elif len(trade) == 0 : # 산 기록이 없을 때
        s_dt = sell['bse_dt'].values[0]
        diff_date.append(working_day(20160101, s_dt))
    else : 
        for _, row in sell.iterrows() :
            s_dt = row['bse_dt']
            t_dt = trade[trade['bse_dt'] <= s_dt]['bse_dt'].values[0]
            trade = trade[trade['bse_dt'] > t_dt]
            diff_date.append(working_day(t_dt, s_dt))
        trade = trade[trade['bse_dt']>s_dt]
        if len(trade) != 0 :
            t_dt = trade['bse_dt'].values[0]
            diff_date.append(working_day(t_dt, 20201231))    
    return np.mean(diff_date)

# %%
stk_df[stk_df['act_id']=='feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b77954945ff183255c9'][stk_df['iem_cd']=='A066130']
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                     act_id    bse_dt   iem_cd  \
# 2321872  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20190401  A066130
# 2321873  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20190403  A066130
# 2321874  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20191105  A066130
# 2321875  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20191106  A066130
# 2321876  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20191107  A066130
# 2321877  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20191122  A066130
# 2321878  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20200103  A066130
# 2321879  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20200226  A066130
# 2321880  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20200228  A066130
# 2321881  feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b...  20200302  A066130
#
#          bnc_qty  tot_aet_amt  stk_par_pr
# 2321872     96.0    1022400.0       500.0
# 2321873      0.0          0.0       500.0
# 2321874   1863.0   13320450.0       500.0
# 2321875   1958.0   14234660.0       500.0
# 2321876   2107.0   14938630.0       500.0
# 2321877   1863.0   12537990.0       500.0
# 2321878   2142.0   16257780.0       500.0
# 2321879   1142.0    8382280.0       500.0
# 2321880    600.0    3870000.0       500.0
# 2321881      0.0          0.0       500.0

# %%
diff_date = stk_hist('feaf418a74ee66caa6b550ea26e1eb12d231a3ceb69d4b77954945ff183255c9', 'A066130')
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
diff_date
# Out:
# 43.0

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Past_d

# %%
stk_df = stk_df.sort_values(by=['bse_dt'])

# %%
train_df['past_d'] = train_df.swifter.progress_bar().apply(lambda x : stk_hist(x['act_id'], x['iem_cd']), axis = 1)
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# Dask Apply:   0%|          | 0/40 [00:00<?, ?it/s]
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
test_df['past_d'] = test_df.apply(lambda x : stk_hist(x['act_id'], x['iem_cd']), axis = 1)
# Out:
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %% [markdown]
# #### user avg past_d : 사용자 별 past_d
# #### iem avg past_d : 종목 별 평균 past_d
# #### ivs  icn avg past_d : 투자성향 별 평균 past_d
# #### mkt_pr_tal_scl_tp_cd : 시가총액 규모 별 평균 past_d
# -> 제대로 하려면 stk_hist 파일 돌려서 다시 구해야 함

# %%
user_avg_pastd = train_df['past_d'].groupby(train_df['act_id']).mean()

# %%
iem_avg_pastd = train_df['past_d'].groupby(train_df['iem_cd']).mean()

# %%
ivs_icn_avg_pastd = train_df['past_d'].groupby(train_df['ivs_icn_cd']).mean()

# %%
user_avg_pastd_test = test_df['past_d'].groupby(test_df['act_id']).mean()

# %%
iem_avg_pastd_test = test_df['past_d'].groupby(test_df['iem_cd']).mean()

# %%
mkt_pr_avg_pastd = train_df['past_d'].groupby(train_df['mkt_pr_tal_scl_tp_cd']).mean()

# %%
train_df['user_avg_past_d'] = train_df.apply(lambda x : user_avg_pastd[x['act_id']], axis = 1)

# %%
train_df['iem_avg_past_d'] = train_df.apply(lambda x : iem_avg_pastd[x['iem_cd']], axis = 1)

# %%
train_df['ivs_icn_past_d'] = train_df.apply(lambda x : ivs_icn_avg_pastd[x['ivs_icn_cd']], axis = 1)

# %%
train_df['mkt_pr_past_d'] = train_df.apply(lambda x : mkt_pr_avg_pastd[x['mkt_pr_tal_scl_tp_cd']], axis = 1)

# %%
test_df['user_avg_past_d'] = test_df.apply(lambda x : user_avg_pastd[x['act_id']] if x['act_id'] in user_avg_pastd else user_avg_pastd_test[x['act_id']], axis = 1)

# %%
test_df['iem_avg_past_d'] = test_df.apply(lambda x : iem_avg_pastd[x['iem_cd']] if x['iem_cd'] in iem_avg_pastd else iem_avg_pastd_test[x['iem_cd']], axis = 1)

# %%
test_df['ivs_icn_past_d'] = test_df.apply(lambda x : ivs_icn_avg_pastd[x['ivs_icn_cd']], axis = 1)

# %%
test_df['mkt_pr_past_d'] = test_df.apply(lambda x : mkt_pr_avg_pastd[x['mkt_pr_tal_scl_tp_cd']], axis = 1)

# %%
train_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
#
#    hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0      11           1               9           3               2
# 1      80           1               9           3               2
# 2       5           1               9           3               2
# 3      22           1               9           3               2
# 4     324           1               9           3               2
#
#    mrz_pdt_tp_sgm_cd  lsg_sgm_cd  ...  iem_krl_nm  btp_cfc_cd  \
# 0                  2           9  ...         101           1
# 1                  2           9  ...        1361           9
# 2                  2           9  ...        2530          12
# 3                  2           9  ...        1969           8
# 4                  2           9  ...        1696          10
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd  past_d  hist_d  user_avg_past_d  \
# 0                     1           1   195.0     6.6        41.074468
# 1                     1           1    86.0    48.0        41.074468
# 2                     2          99     6.0     3.0        41.074468
# 3                     2           1    22.0    13.2        41.074468
# 4                     3          99   347.0   194.4        41.074468
#
#    iem_avg_past_d  ivs_icn_past_d  mkt_pr_past_d
# 0       66.392544       39.918768      58.505146
# 1      101.057144       39.918768      58.505146
# 2       44.857150       39.918768      40.248910
# 3       44.580025       39.918768      40.248910
# 4       81.323587       39.918768      36.059944
#
# [5 rows x 23 columns]

# %%
test_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A032640  20200522
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A160600  20190823
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A234340  20200611
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A131760  20200120
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A293490  20201217
#
#    hist_d submit_id  hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  \
# 0     153  IDX00001       0           1               9           3
# 1     335  IDX00002       0           1               9           3
# 2     139  IDX00003       0           1               9           3
# 3     236  IDX00004       0           1               9           3
# 4       9  IDX00005       0           1               9           3
#
#    cus_aet_stn_cd  ...  mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  \
# 0               2  ...               8         418           4
# 1               2  ...               8        2230          10
# 2               2  ...               8        1515          13
# 3               2  ...               8        2681          13
# 4               2  ...               8        2450          13
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd  past_d  user_avg_past_d  iem_avg_past_d  \
# 0                     1           1   159.0        41.074468       87.701799
# 1                     3          99   354.0        41.074468       33.203922
# 2                     2          99   145.0        41.074468       31.919831
# 3                     3          99   248.0        41.074468       37.868490
# 4                     1           2    10.0        41.074468       15.034166
#
#    ivs_icn_past_d  mkt_pr_past_d
# 0       39.918768      58.505146
# 1       39.918768      36.059944
# 2       39.918768      40.248910
# 3       39.918768      36.059944
# 4       39.918768      58.505146
#
# [5 rows x 24 columns]

# %% [markdown]
# #### hist d :

# %%
train_df["hist_d"] = train_df["hold_d"]*0.6

# %%
train_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
#
#    hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0      11           1               9           3               2
# 1      80           1               9           3               2
# 2       5           1               9           3               2
# 3      22           1               9           3               2
# 4     324           1               9           3               2
#
#    mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                  2           9               5                  5
# 1                  2           9               5                  5
# 2                  2           9               5                  5
# 3                  2           9               5                  5
# 4                  2           9               5                  5
#
#    mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  stk_dit_cd  \
# 0               8         101           1                     1           1
# 1               8        1361           9                     1           1
# 2               8        2530          12                     2          99
# 3               8        1969           8                     2           1
# 4               8        1696          10                     3          99
#
#    past_d  hist_d
# 0   195.0     6.6
# 1    86.0    48.0
# 2     6.0     3.0
# 3    22.0    13.2
# 4   347.0   194.4

# %%
test_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A032640  20200522
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A160600  20190823
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A234340  20200611
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A131760  20200120
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A293490  20201217
#
#    hist_d submit_id  hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  \
# 0     153  IDX00001       0           1               9           3
# 1     335  IDX00002       0           1               9           3
# 2     139  IDX00003       0           1               9           3
# 3     236  IDX00004       0           1               9           3
# 4       9  IDX00005       0           1               9           3
#
#    cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  \
# 0               2                  2           9               5
# 1               2                  2           9               5
# 2               2                  2           9               5
# 3               2                  2           9               5
# 4               2                  2           9               5
#
#    tot_ivs_te_sgm_cd  mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  \
# 0                  5               8         418           4
# 1                  5               8        2230          10
# 2                  5               8        1515          13
# 3                  5               8        2681          13
# 4                  5               8        2450          13
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd  past_d
# 0                     1           1   159.0
# 1                     3          99   354.0
# 2                     2          99   145.0
# 3                     3          99   248.0
# 4                     1           2    10.0

# %% [markdown]
# ## External Data Featuring

# %%
external_path = conf.external_path

# %%
stk_mean_df = pd.read_csv(external_path+'mean_stockdata.csv')

# %%
stk_mean_df['code'] = stk_mean_df.apply(lambda x : 'A' + x['code'], axis = 1)

# %%
stk_mean_df
# Out:
#          code          oepn          high           low         close  \
# 0     A000020  10628.321108  10875.158924  10395.338223  10611.340668
# 1     A000080  13718.842105  13873.710526  13566.907895  14156.565789
# 2     A000180   3205.013040   3268.528117   3137.779136   3229.211084
# 3     A000227  13186.233089  13408.596577  12970.257539  13402.982885
# 4     A000325  18285.819071  18510.423798  18045.867971  18283.928280
# ...       ...           ...           ...           ...           ...
# 2807  A156080  10585.937500  10747.812500  10474.375000  10595.937500
# 2808  A160980  10113.500000  10179.500000   9927.500000  10037.000000
# 2809  A161580  10127.000000  10232.000000   9951.000000  10080.000000
# 2810  A163730  10156.500000  10307.250000  10123.000000  10264.500000
# 2811  A168330  10015.500000  10039.000000   9937.000000   9957.500000
#
#             volume     chage
# 0     4.514417e+05  0.001178
# 1     1.592198e+06  0.000800
# 2     1.243295e+06 -0.000945
# 3     3.864996e+04 -0.000098
# 4     1.757751e+05  0.000082
# ...            ...       ...
# 2807  2.414732e+05  0.007861
# 2808  1.963900e+04  0.000063
# 2809  8.949426e+05  0.001339
# 2810  9.705650e+04  0.016875
# 2811  6.615750e+03 -0.001647
#
# [2812 rows x 7 columns]

# %%
train_df = pd.merge(left = train_df, right = stk_mean_df[['code', 'volume']], how='left', left_on='iem_cd', right_on = 'code')

# %%
test_df = pd.merge(left = test_df, right = stk_mean_df[['code', 'volume']], how='left', left_on='iem_cd', right_on = 'code')

# %% [markdown]
# ## Target Encoding

# %%
target_encoder = TargetEncoder()

# %%
target_encoder.fit(train_df['iem_cd'], train_df['hold_d'])
# Out:
# TargetEncoder(cols=['iem_cd'])

# %%
train_df['iem_cd_te'] = target_encoder.transform(train_df['iem_cd'], train_df['hold_d'])

# %%
test_df['iem_cd_te'] = target_encoder.transform(test_df['iem_cd'], test_df['hold_d'])

# %%
test_df = test_df.fillna(0)

# %%
train_df = train_df.fillna(0)

# %%
#target_encoder.transform(train_df['ivs_icn_cd'], train_df['hold_d'])
# Out:
#         ivs_icn_cd
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# ...            ...
# 681467           4
# 681468           4
# 681469           4
# 681470           4
# 681471           4
#
# [681472 rows x 1 columns]

# %% [markdown]
# ## Drop Features

# %%
train_df = train_df.drop(['act_id', 'iem_cd', 'code', 'byn_dt'], axis = 1)

# %%
used_features = train_df.columns.drop('hold_d')

# %%
test_df = test_df[used_features]

# %%
train_df.columns
# Out:
# Index(['hold_d', 'sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd',
#        'cus_aet_stn_cd', 'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'past_d', 'hist_d', 'volume',
#        'iem_cd_te'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd', 'cus_aet_stn_cd',
#        'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'past_d', 'hist_d', 'volume',
#        'iem_cd_te'],
#       dtype='object')

# %% [markdown]
# ## 03. XGBoost

# %%
col = train_df.columns

# %%
col = col.drop('hold_d')

# %%
TARGET = 'hold_d'

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_df[col], train_df[TARGET], test_size = 0.2)

# %%
model = xgb.XGBRegressor(n_estimators=1000, max_depth=8, min_child_weighteta=0.1, subsample=0.7, colsample_bytree=0.8)

# %% [markdown]
# #### GridSearch

# %%
cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    seed=42,
    nfold=5,
    metrics={'mae'},
    early_stopping_rounds=10
)

# %%
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'eta' :[0.05, 0.1],
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7, 8],
              'min_child_weight': [1, 2, 4, 6],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500, 1000]}

xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

# %%
model.fit(X_train, y_train, verbose=False)
# Out:
# [20:07:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#              min_child_weight=1, min_child_weighteta=0.1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=20,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=0.7, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_grid.fit(X_train, y_train, verbose=False)
# Out:
# Fitting 2 folds for each of 192 candidates, totalling 384 fits
# [18:12:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:12:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:13:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:13:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:14:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:15:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:15:49] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:49] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:16:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:16:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:17:44] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:44] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:19:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:19:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:20:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:20:49] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:49] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:22:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:23:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [18:12:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:13:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:13:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:13:58] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:13:58] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:14:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:15:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:16:51] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:16:51] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:17:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:18:44] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:44] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:20:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:21:05] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:05] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:21:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:23:43] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:43] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:25:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:25:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:26:32] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:32] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:27:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:28:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:28:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:28:44] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:28:44] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [18:12:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:12:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:13:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:13:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:14:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:15:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:15:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:17:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:18:23] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:23] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:19:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:19:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:20:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:22:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:23:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:24:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:25:45] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:45] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:26:49] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:49] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:27:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:27:51] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:51] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:28:52] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:28:52] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [18:12:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:12:56] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:56] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:14:01] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:01] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:15:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:16:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:16:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:17:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:18:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:19:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:19:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:20:00] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:00] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:21:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:23:17] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:17] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:24:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:25:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:25:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:26:39] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:39] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:27:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:28:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:28:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:28:53] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:28:53] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [18:12:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:13:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:13:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:13:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:13:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:14:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:16:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:16:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:16:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:16:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:17:33] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:33] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:18:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:19:54] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:19:54] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:21:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:22:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:24:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:24:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:26:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:27:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:28:15] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:28:15] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:29:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:29:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:30:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [18:30:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:31:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:31:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:32:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:32:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:33:39] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:39] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:35:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:35:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [18:31:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:31:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:32:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:32:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:33:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:34:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:35:23] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:35:23] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [18:30:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:30:52] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:52] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:31:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:31:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:33:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:34:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:35:36] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:35:36] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:36:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:31] WARNING: ../src/learner.cc:573:
# ...
#
#
# [19:27:23] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:27:23] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:28:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:28:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:30:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:31:43] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:43] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [19:15:23] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:15:23] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:17:13] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:13] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:18:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:18:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:18:58] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:18:58] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:20:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:20:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:21:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:21:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:22:43] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:22:43] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:23:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:23:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:24:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:24:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:25:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:26:51] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:26:51] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:27:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:27:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:28:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:28:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:29:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:31:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [19:24:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:24:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:24:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:24:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:25:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:25:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:27:25] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:27:25] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:28:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:28:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:29:39] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:39] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:30:33] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:33] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:31:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [19:32:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:32:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# [19:25:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:25:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:27:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:27:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:28:45] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:28:45] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:29:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:31:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:31:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:32:22] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [19:32:22] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
xgb.plot_importance(model)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgb_grid.score(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_52361/741735724.py in <module>
# ----> 1 xgb_grid.score(X_train, y_train)
#
# NameError: name 'xgb_grid' is not defined

# %%
model.score(X_train, y_train)
# Out:
# 0.9999867422859888

# %% [markdown]
# ## Predict Score

# %%
pred = model.predict(X_valid)

# %%
pred = xgb_grid.predict(X_valid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_52361/57642626.py in <module>
# ----> 1 pred = xgb_grid.predict(X_valid)
#
# NameError: name 'xgb_grid' is not defined

# %%
y_valid.values
# Out:
# array([219,  35,   3, ...,  25,  12,   1])

# %%
np.round(pred)
# Out:
# array([220.,  35.,   3., ...,  25.,  12.,   1.], dtype=float32)

# %%
np.sqrt(mean_squared_error(y_valid.values, np.round(pred)))
# Out:
# 2.091282375926595

# %% [markdown]
# ## 04. Submission

# %%
submission = pd.read_csv(f"{path}"+"sample_submission.csv")

# %%
y_pred = xgb_grid.predict(test_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_52361/438707539.py in <module>
# ----> 1 y_pred = xgb_grid.predict(test_df)
#
# NameError: name 'xgb_grid' is not defined

# %%
y_pred = model.predict(test_df)

# %%
y_pred
# Out:
# array([259.303    , 523.8576   , 229.15703  , ..., 841.5454   ,
#         17.907469 ,   7.0114646], dtype=float32)

# %%
result = []
for i in y_pred:
    result.append(i)

# %%
result
# Out:
# [259.303,
#  523.8576,
#  229.15703,
#  395.1076,
#  13.019421,
#  156.87354,
#  167.76497,
#  883.1249,
#  135.64128,
#  921.77606,
#  194.58713,
#  1020.8924,
#  757.64685,
#  9.980309,
#  17.777895,
#  5.002801,
#  184.72856,
#  115.13598,
#  476.6946,
#  13.079438,
#  9.316253,
#  1003.5899,
#  647.9736,
#  26.607355,
#  3.1882503,
#  112.05197,
#  111.450645,
#  399.88623,
#  686.61896,
#  473.92087,
#  115.154884,
#  114.47834,
#  862.8203,
#  219.88496,
#  19.611372,
#  126.45356,
#  219.78824,
#  1135.1177,
#  218.07008,
#  1080.9559,
#  1127.6259,
#  668.71063,
#  1068.5018,
#  1104.0237,
#  1066.1431,
#  981.7724,
#  1099.0182,
#  1079.1543,
#  1071.439,
#  1067.6843,
#  1106.7365,
#  1081.4132,
#  234.75873,
#  926.97894,
#  898.99664,
#  225.75203,
#  203.33107,
#  792.4443,
#  921.97095,
#  945.256,
#  121.909904,
#  874.97186,
#  874.44977,
#  909.55286,
#  798.10657,
#  892.01556,
#  912.6894,
#  149.17488,
#  199.82379,
#  850.83704,
#  914.36566,
#  835.7928,
#  952.0755,
#  1065.5797,
#  19.842215,
#  245.26102,
#  43.242043,
#  39.967358,
#  242.41171,
#  18.388285,
#  1.8696771,
#  937.42865,
#  1161.9841,
#  896.49774,
#  12.004836,
#  298.6168,
#  232.92534,
#  37.6136,
#  16.562346,
#  7.0965514,
#  1.6118922,
#  361.46326,
#  39.361305,
#  19.912481,
#  1.8903953,
#  15.081039,
#  12.799453,
#  2.8656425,
#  36.773098,
#  166.46236,
#  7.166283,
#  12.810403,
#  64.219444,
#  806.0306,
#  32.813736,
#  154.42697,
#  1.7970017,
#  3.1088152,
#  157.23763,
#  96.554,
#  500.8437,
#  174.75455,
#  117.927345,
#  7.0807595,
#  388.42157,
#  24.723736,
#  19.357937,
#  2.5600045,
#  7.0155163,
#  160.54457,
#  1.8496197,
#  116.609505,
#  412.22006,
#  82.42631,
#  772.8648,
#  821.0599,
#  396.7622,
#  477.36893,
#  816.44055,
#  2.034604,
#  807.2347,
#  47.116585,
#  266.0906,
#  876.9485,
#  136.85541,
#  11.780434,
#  173.09056,
#  843.82446,
#  841.56256,
#  257.37415,
#  180.25743,
#  16.956362,
#  161.13031,
#  12.010942,
#  230.07713,
#  40.113365,
#  143.38669,
#  62.664047,
#  135.00327,
#  64.72681,
#  12.911468,
#  1121.2745,
#  1119.7065,
#  1135.3213,
#  1127.5302,
#  1151.822,
#  653.7578,
#  846.4047,
#  154.3416,
#  8.087621,
#  60.345703,
#  237.71655,
#  2.001938,
#  5.048398,
#  960.2794,
#  13.009699,
#  27.181053,
#  19.904598,
#  4.2810345,
#  1.9730616,
#  7.103511,
#  7.0117,
#  7.0364323,
#  334.86685,
#  1013.1834,
#  868.9248,
#  2.7890093,
#  16.846218,
#  51.027744,
#  14.245867,
#  14.676393,
#  27.656963,
#  8.359951,
#  206.26636,
#  891.59015,
#  727.0666,
#  12.168292,
#  19.973162,
#  32.791992,
#  41.8977,
#  11.94528,
#  15.030097,
#  28.145725,
#  25.032372,
#  51.67705,
#  30.388071,
#  96.11703,
#  354.01166,
#  890.69214,
#  90.25902,
#  132.12856,
#  12.89739,
#  16.498714,
#  72.639565,
#  162.69118,
#  166.79362,
#  142.92374,
#  1003.7153,
#  99.57755,
#  74.890465,
#  140.25859,
#  194.798,
#  51.7174,
#  68.03405,
#  132.63638,
#  125.5612,
#  90.93347,
#  140.88655,
#  99.79473,
#  7.99232,
#  962.5532,
#  94.53022,
#  1.88551,
#  34.970013,
#  60.11184,
#  5.1300063,
#  5.0955253,
#  942.4286,
#  178.14906,
#  406.04153,
#  46.42648,
#  925.7446,
#  282.51474,
#  95.592155,
#  133.63895,
#  657.0995,
#  35.11264,
#  146.64653,
#  132.97556,
#  124.43563,
#  610.0641,
#  769.6026,
#  240.5066,
#  69.332146,
#  208.01935,
#  101.5562,
#  166.67511,
#  94.89975,
#  74.85205,
#  60.253532,
#  205.06856,
#  60.151176,
#  32.42069,
#  11.8513155,
#  5.0752244,
#  155.2323,
#  19.782154,
#  15.05695,
#  919.2529,
#  658.36176,
#  239.74931,
#  9.557799,
#  1170.424,
#  202.81268,
#  12.375236,
#  859.466,
#  92.01144,
#  20.35958,
#  116.52785,
#  127.035355,
#  931.3867,
#  1163.864,
#  1105.3585,
#  826.6943,
#  862.2865,
#  913.6551,
#  1150.5471,
#  872.03546,
#  851.5149,
#  1106.3851,
#  881.59125,
#  1138.4131,
#  17.025276,
#  26.93148,
#  2.9541922,
#  14.891664,
#  25.19186,
#  392.6599,
#  9.898056,
#  53.054615,
#  11.811771,
#  39.869167,
#  33.376736,
#  2.2041273,
#  18.054888,
#  32.214375,
#  24.819473,
#  6.8952084,
#  884.87134,
#  57.955467,
#  6.7151613,
#  7.972683,
#  1.8490702,
#  62.359306,
#  37.084187,
#  107.45318,
#  52.115044,
#  45.120663,
#  62.29998,
#  37.138386,
#  1.9105937,
#  124.23439,
#  59.65682,
#  224.07762,
#  45.01053,
#  447.00552,
#  209.44557,
#  210.45674,
#  229.37234,
#  336.34363,
#  32.98493,
#  222.63655,
#  213.89146,
#  9.955438,
#  7.9949093,
#  27.050608,
#  69.97426,
#  347.35098,
#  208.42519,
#  51.96312,
#  178.8334,
#  316.41223,
#  8.004458,
#  184.58295,
#  60.032715,
#  43.15601,
#  122.14566,
#  168.66754,
#  240.23712,
#  183.94366,
#  195.30095,
#  169.28632,
#  227.55635,
#  119.12011,
#  57.336246,
#  58.25358,
#  30.310963,
#  227.91371,
#  165.867,
#  394.3888,
#  45.098038,
#  35.187527,
#  178.46843,
#  34.98814,
#  86.3582,
#  181.72595,
#  37.184654,
#  26.810545,
#  37.2379,
#  53.26833,
#  221.90791,
#  225.82333,
#  57.21521,
#  251.69429,
#  164.46288,
#  192.7726,
#  243.3574,
#  152.44955,
#  162.2637,
#  206.94617,
#  141.86897,
#  47.85814,
#  141.06459,
#  329.02258,
#  108.88987,
#  476.42426,
#  142.04245,
#  243.63588,
#  183.34886,
#  206.6428,
#  118.54677,
#  169.84009,
#  169.20702,
#  109.59049,
#  223.64244,
#  16.976156,
#  229.6884,
#  82.95049,
#  45.083233,
#  154.20251,
#  184.57451,
#  208.8588,
#  145.70226,
#  142.06984,
#  37.237476,
#  227.50346,
#  220.70863,
#  45.313957,
#  43.21032,
#  118.42871,
#  344.08505,
#  226.17259,
#  132.15892,
#  45.009884,
#  400.08435,
#  20.014912,
#  58.349384,
#  9.84064,
#  355.56293,
#  129.40298,
#  130.14795,
#  621.975,
#  210.13237,
#  800.39655,
#  873.0986,
#  285.97598,
#  121.45139,
#  914.0726,
#  19.887272,
#  858.3867,
#  10.952717,
#  548.6541,
#  119.78748,
#  134.26987,
#  285.66708,
#  916.43634,
#  17.23088,
#  849.53784,
#  130.55933,
#  120.60037,
#  40.464638,
#  267.50317,
#  115.62026,
#  2.4768643,
#  21.28461,
#  129.41426,
#  122.61907,
#  852.9742,
#  104.90494,
#  173.8686,
#  765.47125,
#  168.53328,
#  373.64767,
#  171.33777,
#  167.61186,
#  748.8002,
#  1143.4016,
#  1162.1869,
#  1081.4238,
#  1162.522,
#  139.85605,
#  879.11115,
#  967.50464,
#  10.353503,
#  235.2881,
#  72.3499,
#  10.548282,
#  59.419167,
#  117.44131,
#  108.625854,
#  13.125743,
#  659.5823,
#  468.31573,
#  10.186375,
#  1.9857295,
#  8.030786,
#  246.22084,
#  187.81348,
#  211.41284,
#  7.055101,
#  251.24986,
#  122.03617,
#  260.68735,
#  22.008833,
#  127.716385,
#  209.9492,
#  97.45719,
#  13.084573,
#  132.74721,
#  112.195,
#  210.8805,
#  117.285225,
#  213.26033,
#  271.17874,
#  160.3707,
#  212.07454,
#  284.6461,
#  154.824,
#  55.394062,
#  1005.8794,
#  131.27034,
#  264.61926,
#  28.115606,
#  219.22723,
#  273.68466,
#  1044.2809,
#  321.033,
#  1.991628,
#  6.943928,
#  6.916565,
#  7.047787,
#  132.66722,
#  27.869995,
#  4.988507,
#  14.917493,
#  1107.4171,
#  1101.5692,
#  75.65707,
#  1093.0017,
#  42.40959,
#  26.866306,
#  128.44458,
#  191.69235,
#  24.457798,
#  108.34081,
#  60.12247,
#  43.123707,
#  44.907127,
#  17.08602,
#  123.99427,
#  61.639015,
#  49.519543,
#  57.13411,
#  65.69441,
#  23.19258,
#  37.964867,
#  79.66541,
#  14.615769,
#  18.074944,
#  7.038422,
#  75.24411,
#  76.91058,
#  99.599724,
#  76.9804,
#  15.072656,
#  41.719376,
#  10.037669,
#  92.95568,
#  90.95513,
#  877.2834,
#  132.5161,
#  11.985002,
#  550.9553,
#  67.138565,
#  17.906977,
#  24.799992,
#  188.07819,
#  54.946304,
#  2.0599935,
#  761.1955,
#  14.93302,
#  44.6917,
#  4.9721656,
#  27.991991,
#  10.103596,
#  52.322567,
#  251.34901,
#  81.5928,
#  1.9278548,
#  88.33784,
#  77.46026,
#  37.247707,
#  5.0695257,
#  11.961861,
#  37.42966,
#  857.4117,
#  69.89871,
#  365.77725,
#  268.74716,
#  293.91714,
#  62.575283,
#  300.72617,
#  364.27524,
#  177.70357,
#  368.001,
#  7.238742,
#  124.42308,
#  0.9238976,
#  1.71868,
#  4.9324975,
#  6.9368896,
#  1.8990539,
#  90.51263,
#  62.512264,
#  882.9084,
#  52.861115,
#  835.0613,
#  806.18445,
#  41.81276,
#  41.914642,
#  884.7654,
#  30.404686,
#  72.12822,
#  34.53942,
#  65.50791,
#  735.3185,
#  38.183357,
#  164.62494,
#  9.89867,
#  32.105583,
#  17.195269,
#  1060.8606,
#  15.410542,
#  7.4792614,
#  1.7544376,
#  846.67725,
#  1.8999882,
#  2.1579041,
#  22.465536,
#  15.215209,
#  966.71515,
#  959.6164,
#  903.1244,
#  929.7428,
#  998.78564,
#  143.73695,
#  21.9713,
#  19.974222,
#  264.2105,
#  852.0238,
#  460.65222,
#  859.8254,
#  1013.7706,
#  464.4007,
#  9.688502,
#  137.65129,
#  128.36203,
#  6.9668717,
#  598.5339,
#  694.3724,
#  1.9765759,
#  10.612006,
#  65.612854,
#  6.9175253,
#  43.555515,
#  31.224075,
#  7.9874635,
#  339.1006,
#  28.328123,
#  13.013366,
#  12.104288,
#  2.0504436,
#  60.187157,
#  315.7287,
#  17.908474,
#  646.1209,
#  181.2375,
#  48.062332,
#  875.36884,
#  9.960039,
#  374.98532,
#  47.903072,
#  314.5707,
#  100.55164,
#  3.008377,
#  46.802284,
#  13.029113,
#  11.913195,
#  262.13376,
#  32.647305,
#  8.0746,
#  14.9985,
#  3.0403316,
#  707.24133,
#  751.7521,
#  30.110647,
#  2.999648,
#  4.8209248,
#  7.930946,
#  28.152378,
#  17.008314,
#  103.91498,
#  2.9640155,
#  137.7556,
#  141.80794,
#  713.337,
#  721.619,
#  912.7269,
#  140.67386,
#  8.938033,
#  2.9933937,
#  11.866711,
#  245.10104,
#  851.751,
#  634.97,
#  53.026028,
#  147.5929,
#  112.57717,
#  38.14895,
#  17.053898,
#  38.32327,
#  849.15857,
#  12.111125,
#  202.70374,
#  11.947997,
#  298.44016,
#  293.3296,
#  127.97217,
#  175.55032,
#  181.78174,
#  296.54865,
#  155.9153,
#  23.148495,
#  42.927013,
#  200.38483,
#  899.28644,
#  943.4005,
#  680.2661,
#  636.8,
#  698.6852,
#  891.1732,
#  927.2855,
#  552.55493,
#  661.9157,
#  627.5888,
#  899.07513,
#  515.50635,
#  817.801,
#  1198.6581,
#  910.3428,
#  978.39197,
#  971.00586,
#  997.0717,
#  621.63367,
#  820.99603,
#  382.3877,
#  803.6109,
#  988.74286,
#  854.02075,
#  41.684315,
#  146.0205,
#  927.1755,
#  170.67706,
#  16.998055,
#  4.895221,
#  413.68466,
#  90.87083,
#  242.08325,
#  875.8815,
#  11.9606,
#  23.151138,
#  5.057569,
#  239.57492,
#  227.32108,
#  227.7882,
#  484.10568,
#  924.34644,
#  63.873688,
#  900.23975,
#  46.10294,
#  380.51535,
#  118.15355,
#  7.154145,
#  144.82846,
#  300.7363,
#  57.496483,
#  113.41815,
#  91.95002,
#  5.052292,
#  1.822784,
#  2.1099412,
#  122.66139,
#  235.44763,
#  278.9203,
#  959.4519,
#  789.58185,
#  1002.8804,
#  326.13147,
#  330.09998,
#  846.5255,
#  861.5599,
#  874.0722,
#  885.29224,
#  504.4929,
#  492.64566,
#  942.5258,
#  887.4288,
#  991.4408,
#  378.78925,
#  852.8999,
#  959.0345,
#  27.964869,
#  14.961389,
#  19.866016,
#  6.9875894,
#  7.952601,
#  79.11159,
#  378.09955,
#  320.042,
#  12.6861725,
#  28.083363,
#  41.516968,
#  117.5203,
#  53.12541,
#  49.967564,
#  26.988487,
#  4.973166,
#  264.52725,
#  104.68737,
#  40.16875,
#  30.195778,
#  118.70122,
#  138.47832,
#  17.04969,
#  79.4429,
#  181.18388,
#  376.41025,
#  9.932756,
#  13.053805,
#  17.057358,
#  134.30708,
#  966.1974,
#  658.0457,
#  393.16937,
#  201.57753,
#  509.28513,
#  208.86436,
#  192.7036,
#  9.971474,
#  1.817361,
#  10.047682,
#  57.41385,
#  32.72638,
#  37.97463,
#  15.0351095,
#  265.97348,
#  6.896681,
#  10.010269,
#  44.94457,
#  44.526695,
#  143.28497,
#  3.6261954,
#  2.9490364,
#  145.8319,
#  42.65675,
#  3.6292648,
#  9.904293,
#  946.4821,
#  10.255771,
#  16.85442,
#  22.075083,
#  1.9332283,
#  102.63392,
#  8.160664,
#  2.9105737,
#  3.1283839,
#  1.8179643,
#  14.961702,
#  69.61931,
#  48.015793,
#  6.869019,
#  138.97069,
#  15.108829,
#  100.432915,
#  274.31985,
#  499.49646,
#  44.962116,
#  14.990844,
#  9.949567,
#  17.027496,
#  28.103027,
#  18.057226,
#  25.20812,
#  99.31031,
#  482.3997,
#  895.476,
#  346.12106,
#  499.70987,
#  882.02844,
#  116.634674,
#  1.9311148,
#  871.08606,
#  6.9121532,
#  101.27701,
#  47.219753,
#  642.3005,
#  21.477228,
#  895.5567,
#  914.97833,
#  857.49615,
#  846.1612,
#  882.79724,
#  242.13904,
#  28.305634,
#  407.23083,
#  582.93976,
#  628.0485,
#  474.65735,
#  26.751263,
#  2.8672593,
#  23.12189,
#  2.0673368,
#  35.25001,
#  53.197872,
#  30.282074,
#  44.587402,
#  20.058094,
#  17.069784,
#  57.317856,
#  85.1378,
#  38.20567,
#  47.602406,
#  40.02112,
#  17.052721,
#  81.69034,
#  1.8942329,
#  40.43535,
#  16.739134,
#  51.81549,
#  16.92211,
#  20.133558,
#  9.887347,
#  3.0900986,
#  33.073204,
#  47.70817,
#  12.0603075,
#  37.5564,
#  13.182342,
#  15.018407,
#  15.0151415,
#  12.048143,
#  1.8420222,
#  37.58657,
#  32.58347,
#  960.3192,
#  780.0206,
#  947.33,
#  927.5353,
#  898.94305,
#  405.39062,
#  962.9851,
#  909.6885,
#  140.37628,
#  893.3044,
#  385.72375,
#  164.27052,
#  163.05261,
#  95.18461,
#  158.31244,
#  92.026474,
#  215.10463,
#  253.41508,
#  154.09523,
#  234.01114,
#  253.91692,
#  46.33961,
#  235.65121,
#  89.26865,
#  104.04447,
#  2.9650633,
#  30.134058,
#  32.230568,
#  945.8491,
#  32.280045,
#  31.94123,
#  906.40186,
#  43.56622,
#  6.815152,
#  56.463566,
#  40.254894,
#  7.4866033,
#  11.936013,
#  83.7984,
#  17.160114,
#  159.01407,
#  227.62273,
#  32.202656,
#  46.89221,
#  19.993654,
#  13.025788,
#  264.34763,
#  21.912205,
#  90.12794,
#  42.149708,
#  42.132236,
#  30.1758,
#  118.60366,
#  126.513916,
#  29.71297,
#  2.916169,
#  93.0419,
#  212.15729,
#  165.08835,
#  212.04839,
#  44.747265,
#  37.98752,
#  30.455046,
#  351.7756,
#  190.2351,
#  10.072211,
#  100.21794,
#  52.906414,
#  218.76265,
#  19.970444,
#  32.246582,
#  32.09694,
#  34.79595,
#  20.000223,
#  34.916813,
#  322.19293,
#  ...]

# %%
submission["hold_d"] = np.round(result)

# %%
submission
# Out:
#       submit_id  hold_d
# 0      IDX00001   259.0
# 1      IDX00002   524.0
# 2      IDX00003   229.0
# 3      IDX00004   395.0
# 4      IDX00005    13.0
# ...         ...     ...
# 70591  IDX70592    38.0
# 70592  IDX70593   173.0
# 70593  IDX70594   842.0
# 70594  IDX70595    18.0
# 70595  IDX70596     7.0
#
# [70596 rows x 2 columns]

# %%
submission.to_csv("./result/xgboost(iem_cd_target_encoding lib with hist_d volume).csv", index = False)
