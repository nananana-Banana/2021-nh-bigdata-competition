# %%
import os
import sys
sys.path.append('../../')

import pandas as pd
import xgboost as xgb
import numpy as np
import swifter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import GridSearchCV
from datetime import datetime, timedelta
from tqdm import tqdm, tqdm_notebook
from category_encoders import TargetEncoder
import core.config as conf

# %%
tqdm_notebook().pandas()
# Out:
# <ipython-input-2-cb18d13d338b>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tqdm_notebook().pandas()
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ## 01. Train Data Load

# %%
## load preprocessing data (past_d)
# train_df = pd.read_csv('./result/train_past_d.csv')
# test_df = pd.read_csv('./result/test_past_d.csv')

# %%
path = conf.data_path

# %%
# train_df = pd.read_csv(f'{path}'+'stk_hld_train.csv')
train_df = pd.read_csv('~/Study/' + conf.data_path[2:] + 'stk_hld_train.csv') # 아정

# %%
train_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
#
#    hold_d
# 0      11
# 1      80
# 2       5
# 3      22
# 4     324

# %%
# cus_df = pd.read_csv(f'{path}'+'cus_info.csv')
cus_df = pd.read_csv('~/Study/' + conf.data_path[2:] + 'cus_info.csv') # 아정

# %%
cus_df.head()
# Out:
#                                               act_id  sex_dit_cd  \
# 0  64aae8dd71e5c0761000db9f9a6779e504e7a4aa9dc097...           1
# 1  5f7c3a8f37d9c268d06130ff0be5d32a1b9ef68c13049f...           1
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...           2
# 3  6d497facfa1ea5901b827335553331f8555fec02a8184f...           2
# 4  b727c78d2cfc246c97b677f29a034399a0c7e7873fff44...           1
#
#    cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  \
# 0               4          99               1                  2           3
# 1               6           4               4                  2           5
# 2               7           4               3                  2           5
# 3               6           4               4                  8           5
# 4               5           2               2                  2           5
#
#    tco_cus_grd_cd  tot_ivs_te_sgm_cd  mrz_btp_dit_cd
# 0               3                  6              16
# 1               2                  6               1
# 2               5                  6               9
# 3               3                  6              16
# 4               5                  5              16

# %%
# iem_df = pd.read_csv(f'{path}'+'iem_info_20210902.csv')
iem_df = pd.read_csv('~/Study/' + conf.data_path[2:] +'iem_info_20210902.csv')  # 아정

# %%
iem_df.head()
# Out:
#     iem_cd iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  stk_dit_cd
# 0  A000020       동화약품           8                     2          99
# 1  A000080      하이트진로          14                     2           1
# 2  A000180     성창기업지주           5                     3          99
# 3  A000227    유유제약2우B           8                    99          99
# 4  A000325     노루홀딩스우           2                    99          99

# %% [markdown]
# ### 종목 Label Encoding

# %%
L_encoder = LabelEncoder()
L_encoder.fit(iem_df["iem_krl_nm"])
# Out:
# LabelEncoder()

# %%
iem_df['iem_krl_nm'] = L_encoder.transform(iem_df["iem_krl_nm"])

# %%
train_df = pd.merge(left = train_df, right = cus_df, how='left', on='act_id')

# %%
train_df = pd.merge(train_df, iem_df, how='left', on='iem_cd')

# %% [markdown]
# ## 02. Test Data Load

# %%
# test_df = pd.read_csv(f'{path}'+'stk_hld_test.csv')
test_df = pd.read_csv('~/Study/' + conf.data_path[2:] +'stk_hld_test.csv')  # 아정

# %%
test_df = pd.merge(left = test_df, right = cus_df, how='left', on='act_id')

# %%
test_df = pd.merge(test_df, iem_df, how='left', on='iem_cd')

# %%
test_df.head()
# Out:
#                                               act_id   iem_cd    byn_dt  \
# 0  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A032640  20200522
# 1  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A160600  20190823
# 2  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A234340  20200611
# 3  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A131760  20200120
# 4  0ad104dbed99be0cd858aa772765ddedade554601a981b...  A293490  20201217
#
#    hist_d submit_id  hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  \
# 0     153  IDX00001       0           1               9           3
# 1     335  IDX00002       0           1               9           3
# 2     139  IDX00003       0           1               9           3
# 3     236  IDX00004       0           1               9           3
# 4       9  IDX00005       0           1               9           3
#
#    cus_aet_stn_cd  mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  \
# 0               2                  2           9               5
# 1               2                  2           9               5
# 2               2                  2           9               5
# 3               2                  2           9               5
# 4               2                  2           9               5
#
#    tot_ivs_te_sgm_cd  mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  \
# 0                  5               8         418           4
# 1                  5               8        2230          10
# 2                  5               8        1515          13
# 3                  5               8        2681          13
# 4                  5               8        2450          13
#
#    mkt_pr_tal_scl_tp_cd  stk_dit_cd
# 0                     1           1
# 1                     3          99
# 2                     2          99
# 3                     3          99
# 4                     1           2

# %% [markdown]
# ## 03. Stock Hist

# %%
# stk_df = pd.read_csv(f'{path}'+'stk_bnc_hist.csv')
stk_df = pd.read_csv('~/Study/' + conf.data_path[2:] +'stk_bnc_hist.csv')  # 아정

# %%
stk_df.head()
# Out:
#                                               act_id    bse_dt   iem_cd  \
# 0  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200820  A008770
# 1  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200623  A008770
# 2  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20160104  A005940
# 3  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200814  A005930
# 4  1119c23c3a504ca7b75060277410c0f6fb9018ec7638c2...  20200623  A005930
#
#    bnc_qty  tot_aet_amt  stk_par_pr
# 0     40.0    2828000.0      5000.0
# 1     20.0    1390000.0      5000.0
# 2    311.0    2982490.0      5000.0
# 3     40.0    2320000.0       100.0
# 4     20.0    1028000.0       100.0

# %% [markdown]
# ## 04. Data Preprocessing

# %% [markdown]
# ### hist d :

# %%
train_df["hist_d"] = train_df["hold_d"]*0.6

# %%
def working_day(s_dt, e_dt) : # 공휴일 제외
    s_dt = str(s_dt).split('.')[0]
    e_dt = str(e_dt).split('.')[0]
    s_dt = s_dt[:4] + '-' + s_dt[4:6] + '-' + s_dt[6:]
    e_dt = e_dt[:4] + '-' + e_dt[4:6] + '-' + e_dt[6:]
    return np.busday_count(s_dt, e_dt, weekmask='1111100')

# %% [markdown]
# ### External Data Featuring
# - 종목 별 volume feature 추가

# %%
external_path = conf.external_path
print(external_path)
# Out:
# ~/2021-nh-bigdata-competition/external/result/

# %%
# stk_mean_df = pd.read_csv(external_path+'mean_stockdata.csv')
stk_mean_df = pd.read_csv('~/Study/' + external_path[2:] +'mean_stockdata.csv') # 아정

# %%
stk_mean_df['code'] = stk_mean_df.apply(lambda x : 'A' + x['code'], axis = 1)

# %%
stk_mean_df
# Out:
#          code          open          high           low         close  \
# 0     A000020  10628.321108  10875.158924  10395.338223  10611.340668
# 1     A000030  13718.842105  13873.710526  13566.907895  14156.565789
# 2     A000040   3205.013040   3268.528117   3137.779136   3229.211084
# 3     A000050  13186.233089  13408.596577  12970.257539  13402.982885
# 4     A000060  18285.819071  18510.423798  18045.867971  18283.928280
# ...       ...           ...           ...           ...           ...
# 2807  A371470  10585.937500  10747.812500  10474.375000  10595.937500
# 2808  A371870  10113.500000  10179.500000   9927.500000  10037.000000
# 2809  A372330  10127.000000  10232.000000   9951.000000  10080.000000
# 2810  A373490  10156.500000  10307.250000  10123.000000  10264.500000
# 2811  A373790  10015.500000  10039.000000   9937.000000   9957.500000
#
#             volume    change
# 0     4.514417e+05  0.001178
# 1     1.592198e+06  0.000800
# 2     1.243295e+06 -0.000945
# 3     3.864996e+04 -0.000098
# 4     1.757751e+05  0.000082
# ...            ...       ...
# 2807  2.414732e+05  0.007861
# 2808  1.963900e+04  0.000063
# 2809  8.949426e+05  0.001339
# 2810  9.705650e+04  0.016875
# 2811  6.615750e+03 -0.001647
#
# [2812 rows x 7 columns]

# %%
train_df = pd.merge(left = train_df, right = stk_mean_df[['code', 'volume']], how='left', left_on='iem_cd', right_on = 'code')

# %%
test_df = pd.merge(left = test_df, right = stk_mean_df[['code', 'volume']], how='left', left_on='iem_cd', right_on = 'code')

# %% [markdown]
# ### Target Encoding
# 종목 별 hold_d를 사용해서 종목 코드를 target encoding

# %%
target_encoder = TargetEncoder()

# %%
target_encoder.fit(train_df['iem_cd'], train_df['hold_d'])
# Out:
# TargetEncoder(cols=['iem_cd'])

# %%
train_df['iem_cd_te'] = target_encoder.transform(train_df['iem_cd'], train_df['hold_d'])

# %%
test_df['iem_cd_te'] = target_encoder.transform(test_df['iem_cd'], test_df['hold_d'])

# %%
test_df = test_df.fillna(0)

# %%
train_df = train_df.fillna(0)

# %%
#target_encoder.transform(train_df['ivs_icn_cd'], train_df['hold_d'])

# %% [markdown]
# ### past_d 계산
# user 별 종목 past_d

# %%
# id_stk_dur_df = pd.read_csv(conf.data_path + 'id_stk_dur_list.csv')
id_stk_dur_df = pd.read_csv('~/Study/' + conf.data_path[2:] + 'id_stk_dur_list.csv') # 아정

# %%
train_df = pd.merge(train_df, id_stk_dur_df[['act_id', 'iem_cd', 'act_past_d_mean']], how = 'left', on = ['act_id', 'iem_cd'])
train_df
# Out:
#                                                    act_id   iem_cd    byn_dt  \
# 0       0ad104dbed99be0cd858aa772765ddedade554601a981b...  A006360  20180726
# 1       0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005930  20180131
# 2       0ad104dbed99be0cd858aa772765ddedade554601a981b...  A005070  20180517
# 3       0ad104dbed99be0cd858aa772765ddedade554601a981b...  A003520  20201112
# 4       0ad104dbed99be0cd858aa772765ddedade554601a981b...  A002310  20180905
# ...                                                   ...      ...       ...
# 681467  4561928f2825f6389f228088ac807a9fb4575ffdcbc47a...  A260660  20180831
# 681468  4561928f2825f6389f228088ac807a9fb4575ffdcbc47a...  A271980  20201027
# 681469  4561928f2825f6389f228088ac807a9fb4575ffdcbc47a...  A289080  20181121
# 681470  4561928f2825f6389f228088ac807a9fb4575ffdcbc47a...  A307930  20200214
# 681471  4561928f2825f6389f228088ac807a9fb4575ffdcbc47a...  A308100  20200116
#
#         hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0           11           1               9           3               2
# 1           80           1               9           3               2
# 2            5           1               9           3               2
# 3           22           1               9           3               2
# 4          324           1               9           3               2
# ...        ...         ...             ...         ...             ...
# 681467       1           1               4           4               2
# 681468       1           1               4           4               2
# 681469       1           1               4           4               2
# 681470       1           1               4           4               2
# 681471       1           1               4           4               2
#
#         mrz_pdt_tp_sgm_cd  lsg_sgm_cd  ...  mrz_btp_dit_cd  iem_krl_nm  \
# 0                       2           9  ...               8         101
# 1                       2           9  ...               8        1361
# 2                       2           9  ...               8        2530
# 3                       2           9  ...               8        1969
# 4                       2           9  ...               8        1696
# ...                   ...         ...  ...             ...         ...
# 681467                  2           3  ...               8        1752
# 681468                  2           3  ...               8        2344
# 681469                  2           3  ...               8         521
# 681470                  2           3  ...               8        2460
# 681471                  2           3  ...               8         750
#
#         btp_cfc_cd  mkt_pr_tal_scl_tp_cd  stk_dit_cd  hist_d     code  \
# 0                1                     1           1     6.6  A006360
# 1                9                     1           1    48.0  A005930
# 2               12                     2          99     3.0  A005070
# 3                8                     2           1    13.2  A003520
# 4               10                     3          99   194.4  A002310
# ...            ...                   ...         ...     ...      ...
# 681467          10                     3          99     0.6  A260660
# 681468           8                     2          99     0.6  A271980
# 681469           2                     2          99     0.6  A289080
# 681470           2                     3          99     0.6  A307930
# 681471           7                     3          99     0.6  A308100
#
#               volume  iem_cd_te  act_past_d_mean
# 0       5.609763e+05  23.934985              6.5
# 1       8.282941e+06  35.437256             86.0
# 2       6.215593e+05  20.464120              6.0
# 3       4.134687e+06  19.122137             22.0
# 4       4.212912e+04  27.660819            347.0
# ...              ...        ...              ...
# 681467  6.174929e+05  14.380000              1.0
# 681468  2.948565e+05  14.700000              1.0
# 681469  6.089245e+06  11.607744              1.0
# 681470  9.100245e+05  16.943609              1.0
# 681471  2.625307e+05  13.192593              1.0
#
# [681472 rows x 22 columns]

# %%
test_df = pd.merge(test_df, id_stk_dur_df[['act_id', 'iem_cd', 'act_past_d_mean']], how = 'left', on = ['act_id', 'iem_cd'])

# %% [markdown]
# ### 투자성향 별 past_d 계산

# %%
# ivs_past_df = pd.read_csv(conf.data_path + 'preprocessing/ivs_past_d_mean.csv')
ivs_past_df = pd.read_csv('~/Study/' + conf.data_path[2:] + 'preprocessing/ivs_past_d_mean.csv')  # 아정

# %%
train_df = pd.merge(train_df, ivs_past_df, how = 'left', on = ['iem_cd', 'ivs_icn_cd'])

# %%
test_df = pd.merge(test_df, ivs_past_df, how = 'left', on = ['iem_cd', 'ivs_icn_cd'])

# %%
train_df = train_df.fillna(0)
test_df = test_df.fillna(0)

# %% [markdown]
# ### Drop Features

# %%
train_df = train_df.drop(['act_id', 'iem_cd', 'code', 'byn_dt'], axis = 1)

# %%
used_features = train_df.columns.drop('hold_d')

# %%
test_df = test_df[used_features]

# %%
train_df.columns
# Out:
# Index(['hold_d', 'sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd',
#        'cus_aet_stn_cd', 'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'hist_d', 'volume', 'iem_cd_te',
#        'act_past_d_mean', 'ivs_past_d_mean'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd', 'cus_aet_stn_cd',
#        'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'hist_d', 'volume', 'iem_cd_te',
#        'act_past_d_mean', 'ivs_past_d_mean'],
#       dtype='object')

# %%
train_df
# Out:
#         hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0           11           1               9           3               2
# 1           80           1               9           3               2
# 2            5           1               9           3               2
# 3           22           1               9           3               2
# 4          324           1               9           3               2
# ...        ...         ...             ...         ...             ...
# 681467       1           1               4           4               2
# 681468       1           1               4           4               2
# 681469       1           1               4           4               2
# 681470       1           1               4           4               2
# 681471       1           1               4           4               2
#
#         mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                       2           9               5                  5
# 1                       2           9               5                  5
# 2                       2           9               5                  5
# 3                       2           9               5                  5
# 4                       2           9               5                  5
# ...                   ...         ...             ...                ...
# 681467                  2           3               4                  3
# 681468                  2           3               4                  3
# 681469                  2           3               4                  3
# 681470                  2           3               4                  3
# 681471                  2           3               4                  3
#
#         mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  \
# 0                    8         101           1                     1
# 1                    8        1361           9                     1
# 2                    8        2530          12                     2
# 3                    8        1969           8                     2
# 4                    8        1696          10                     3
# ...                ...         ...         ...                   ...
# 681467               8        1752          10                     3
# 681468               8        2344           8                     2
# 681469               8         521           2                     2
# 681470               8        2460           2                     3
# 681471               8         750           7                     3
#
#         stk_dit_cd  hist_d        volume  iem_cd_te  act_past_d_mean  \
# 0                1     6.6  5.609763e+05  23.934985              6.5
# 1                1    48.0  8.282941e+06  35.437256             86.0
# 2               99     3.0  6.215593e+05  20.464120              6.0
# 3                1    13.2  4.134687e+06  19.122137             22.0
# 4               99   194.4  4.212912e+04  27.660819            347.0
# ...            ...     ...           ...        ...              ...
# 681467          99     0.6  6.174929e+05  14.380000              1.0
# 681468          99     0.6  2.948565e+05  14.700000              1.0
# 681469          99     0.6  6.089245e+06  11.607744              1.0
# 681470          99     0.6  9.100245e+05  16.943609              1.0
# 681471          99     0.6  2.625307e+05  13.192593              1.0
#
#         ivs_past_d_mean
# 0             39.551724
# 1             55.771863
# 2             25.934524
# 3             24.164948
# 4             42.586207
# ...                 ...
# 681467        17.975904
# 681468        15.159763
# 681469        15.371429
# 681470        24.973684
# 681471        11.487805
#
# [681472 rows x 19 columns]

# %% [markdown]
# ### Data Scaling
#
# Train/Test 데이터에 대해 정규화 수행
# sklearn의 정규화 함수 이용
# - StandardScalar
# - MinMaxScalar
# - MaxAbsScalar
# - RobustScalar

# %%
# 피처 각각에 대한 scaling을 수행하는 함수를 정의합니다.
def standard_scaling(df, scale_columns):
    for col in scale_columns:
        series_mean = df[col].mean()
        series_std = df[col].std()
        df[col] = df[col].apply(lambda x: (x-series_mean)/series_std)
    return df

# %%
# 피처 각각에 대한 scaling을 수행합니다.
# scale_columns = ['hold_d', 'hist_d', 'volume', 'iem_cd_te', 'act_past_d_mean','ivs_past_d_mean']
scale_columns = ['hist_d', 'volume', 'iem_cd_te', 'act_past_d_mean','ivs_past_d_mean']
df = standard_scaling(train_df, scale_columns)

# %%
# 피처 각각에 대한 scaling을 수행합니다.
scale_columns = ['hist_d', 'volume', 'iem_cd_te', 'act_past_d_mean','ivs_past_d_mean']
df = standard_scaling(test_df, scale_columns)

# %% [markdown]
# ## 05. XGBoost
# model : 기본 XGBoost 모델
# xgb_grid : GridSearch libarary를 통해서 model 최적 파라미터 구한 모델
# * 둘 중 하나로 테스트해보면 되는데 xgb_grid는 정확도가 올라가는 대신 시간 매우 오래 걸림

# %%
train_df
# Out:
#         hold_d  sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0           11           1               9           3               2
# 1           80           1               9           3               2
# 2            5           1               9           3               2
# 3           22           1               9           3               2
# 4          324           1               9           3               2
# ...        ...         ...             ...         ...             ...
# 681467       1           1               4           4               2
# 681468       1           1               4           4               2
# 681469       1           1               4           4               2
# 681470       1           1               4           4               2
# 681471       1           1               4           4               2
#
#         mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                       2           9               5                  5
# 1                       2           9               5                  5
# 2                       2           9               5                  5
# 3                       2           9               5                  5
# 4                       2           9               5                  5
# ...                   ...         ...             ...                ...
# 681467                  2           3               4                  3
# 681468                  2           3               4                  3
# 681469                  2           3               4                  3
# 681470                  2           3               4                  3
# 681471                  2           3               4                  3
#
#         mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  \
# 0                    8         101           1                     1
# 1                    8        1361           9                     1
# 2                    8        2530          12                     2
# 3                    8        1969           8                     2
# 4                    8        1696          10                     3
# ...                ...         ...         ...                   ...
# 681467               8        1752          10                     3
# 681468               8        2344           8                     2
# 681469               8         521           2                     2
# 681470               8        2460           2                     3
# 681471               8         750           7                     3
#
#         stk_dit_cd    hist_d    volume  iem_cd_te  act_past_d_mean  \
# 0                1 -0.163197 -0.288372   0.515073        -0.295958
# 1                1  1.147304  1.593348   1.871933         1.254545
# 2               99 -0.277154 -0.273609   0.105634        -0.305710
# 3                1  0.045723  0.582485  -0.052673         0.006341
# 4               99  5.781538 -0.414807   0.954589         6.344876
# ...            ...       ...       ...        ...              ...
# 681467          99 -0.353125 -0.274600  -0.612077        -0.403226
# 681468          99 -0.353125 -0.353221  -0.574328        -0.403226
# 681469          99 -0.353125  1.058779  -0.939105        -0.403226
# 681470          99 -0.353125 -0.203314  -0.309662        -0.403226
# 681471          99 -0.353125 -0.361098  -0.752149        -0.403226
#
#         ivs_past_d_mean
# 0              0.520452
# 1              1.327972
# 2             -0.157480
# 3             -0.245578
# 4              0.671524
# ...                 ...
# 681467        -0.553700
# 681468        -0.693901
# 681469        -0.683364
# 681470        -0.205315
# 681471        -0.876710
#
# [681472 rows x 19 columns]

# %%
col = train_df.columns

# %%
col = col.drop('hold_d')

# %%
TARGET = 'hold_d'

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_df[col], train_df[TARGET], test_size = 0.2)

# %%
model = xgb.XGBRegressor(n_estimators=1000, max_depth=8, min_child_weighteta=0.1, subsample=0.7, colsample_bytree=0.8)

# %% [markdown]
# #### GridSearch

# %%
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'eta' :[0.05, 0.1],
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7, 8],
              'min_child_weight': [1, 2, 4, 6],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500, 1000]}

xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

# %%
model.fit(X_train, y_train, verbose=False)
# Out:
# [12:42:48] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:541:
# Parameters: { min_child_weighteta } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#              min_child_weight=1, min_child_weighteta=0.1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=8,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=0.7, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_grid.fit(X_train, y_train, verbose=False)
# Out:
# Fitting 2 folds for each of 192 candidates, totalling 384 fits
# [13:56:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:54] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:54] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:00:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:00:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:17] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:17] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:02:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:02:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:04:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:04:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:05:05] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:05:05] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:05:54] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:05:54] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:07:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:07:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:09:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:09:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:10:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:13:48] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:13:48] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:56:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:00:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:00:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:03:14] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:03:14] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:04:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:04:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:06:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:06:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:07:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:07:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:08:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:08:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:09:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:09:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:10:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:10:58] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:58] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:13:15] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:13:15] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:14:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:14:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:56:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:34] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:34] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:42] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:42] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:02:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:02:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:03:17] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:03:17] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:04:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:04:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:04:56] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:04:56] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:06:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:06:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:08:23] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:08:23] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:09:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:09:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:11:11] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:11:11] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:20] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:20] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:13:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:13:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:14:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:14:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:56:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:00:17] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:00:17] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:02:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:02:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:03:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:03:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:05:13] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:05:13] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:06:01] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:06:01] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:06:58] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:06:58] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:08:55] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:08:55] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:10:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:11:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:11:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:11:56] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:11:56] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:13:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:13:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:14:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:14:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:15:45] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:15:45] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [13:56:57] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:56:57] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:57:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:57:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:58:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:58:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [13:59:44] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:59:44] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:01:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:01:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:02:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:02:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:03:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:03:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:04:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:04:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:05:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:05:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:07:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:07:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:08:15] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:08:15] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:10:12] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:10:12] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:12:00] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:00] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:13:07] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:13:07] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:13:41] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:13:41] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:14:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:14:24] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:15:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:15:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:15:45] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:15:45] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [14:15:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:15:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:15:52] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:15:52] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:16:34] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:16:34] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:17:52] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:17:52] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:18:40] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:18:40] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:19:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:19:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:21:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:21:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# /home/nyongja/anaconda3/envs/nh2021/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [14:17:03] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:17:03] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:17:52] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:17:52] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:19:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:19:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:20:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:20:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:21:13] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [14:21:13] WARNING: ../src/learner.cc:573:
# ...
#
#
# [15:11:53] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:53] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:12:33] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:12:33] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:13:52] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:52] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:15:30] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:15:30] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:16:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:16:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:17:08] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:17:08] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:18:04] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:18:04] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:19:59] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:19:59] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [15:04:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:04:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:05:06] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:05:06] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:07:00] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:07:00] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:08:46] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:08:46] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:09:53] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:09:53] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:10:26] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:10:26] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:11:09] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:09] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:11:50] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:50] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:13:13] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:13] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:14:29] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:14:29] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:15:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:15:19] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:17:02] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:17:02] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:18:31] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:18:31] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:19:28] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:19:28] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:20:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:20:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
#
# [15:09:37] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:09:37] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:10:10] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:10:10] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:11:16] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:16] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:12:38] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:12:38] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:13:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:14:35] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:14:35] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:16:18] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:16:18] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:17:05] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:17:05] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:18:36] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:18:36] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:20:27] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:20:27] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:21:21] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:21:21] WARNING: ../src/learner.cc:573:
# Parameters: { "min_child_weighteta", "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
import joblib

# %%
joblib.dump(xgb_grid, 'xgb_gridcv.pkl')
# Out:
# ['xgb_gridcv.pkl']

# %%
xgb.plot_importance(model)

# %%
xgb_grid.score(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-67-e4ce798eed7b> in <module>
# ----> 1 xgb_grid.score(X_train, y_train)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in score(self, X, y)
#     450         score : float
#     451         """
# --> 452         self._check_is_fitted('score')
#     453         if self.scorer_ is None:
#     454             raise ValueError("No score function explicitly defined, "
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _check_is_fitted(self, method_name)
#     468                                  % (type(self).__name__, method_name))
#     469         else:
# --> 470             check_is_fitted(self)
#     471
#     472     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1018
#    1019     if not attrs:
# -> 1020         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1021
#    1022
#
# NotFittedError: This GridSearchCV instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
model.score(X_train, y_train)
# Out:
# 0.9999811210739691

# %% [markdown]
# ## Predict Score

# %%
pred = model.predict(X_valid)

# %%
pred = xgb_grid.predict(X_valid)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-175-b2501b2e592f> in <module>
# ----> 1 pred = xgb_grid.predict(X_valid)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in predict(self, X)
#     484
#     485         """
# --> 486         self._check_is_fitted('predict')
#     487         return self.best_estimator_.predict(X)
#     488
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _check_is_fitted(self, method_name)
#     468                                  % (type(self).__name__, method_name))
#     469         else:
# --> 470             check_is_fitted(self)
#     471
#     472     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1018
#    1019     if not attrs:
# -> 1020         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1021
#    1022
#
# NotFittedError: This GridSearchCV instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
y_valid.values
# Out:
# array([ 1,  1,  9, ..., 24,  5,  6])

# %%
np.round(pred)
# Out:
# array([ 1.,  1., 10., ..., 24.,  5.,  6.], dtype=float32)

# %%
np.sqrt(mean_squared_error(y_valid.values, np.round(pred)))
# Out:
# 1.3892645997977562

# %% [markdown]
# ## 04. Submission

# %%
# submission = pd.read_csv(f"{path}"+"sample_submission.csv")
submission = pd.read_csv('~/Study/' + conf.data_path[2:] +"sample_submission.csv")

# %%
y_pred = xgb_grid.predict(test_df)

# %%
y_pred = model.predict(test_df)

# %%
y_pred
# Out:
# array([ 32.142685  ,  90.395905  ,  27.992163  , ..., 240.11702   ,
#          0.99234277,   0.8504942 ], dtype=float32)

# %%
result = []
for i in y_pred:
    result.append(i)

# %%
result
# Out:
# [32.142685,
#  90.395905,
#  27.992163,
#  59.885803,
#  0.73724836,
#  13.663478,
#  15.949343,
#  216.73703,
#  9.410539,
#  136.79047,
#  23.299776,
#  396.55096,
#  129.29411,
#  1.1357872,
#  1.8457408,
#  1.0217003,
#  18.619587,
#  5.281081,
#  74.53543,
#  1.0547683,
#  0.62090075,
#  378.14435,
#  117.97628,
#  1.3559144,
#  0.86596394,
#  4.9410625,
#  5.897606,
#  59.600266,
#  134.14713,
#  73.54723,
#  5.3305464,
#  4.5757422,
#  261.34216,
#  24.939194,
#  1.4646723,
#  8.24114,
#  24.514153,
#  384.93665,
#  25.40533,
#  338.78506,
#  363.15106,
#  125.88867,
#  320.67352,
#  362.2997,
#  355.0998,
#  168.82643,
#  322.1561,
#  386.68314,
#  391.09174,
#  384.97977,
#  374.67694,
#  320.99628,
#  27.869473,
#  190.97173,
#  199.59767,
#  29.639599,
#  23.834114,
#  187.19334,
#  187.51945,
#  214.7311,
#  6.8251953,
#  200.25528,
#  196.20396,
#  222.2639,
#  169.1819,
#  222.84116,
#  197.75287,
#  7.6928344,
#  21.486958,
#  194.71434,
#  216.60417,
#  224.62181,
#  199.17477,
#  371.61136,
#  0.72803175,
#  30.65249,
#  1.0044757,
#  0.97435844,
#  30.763596,
#  0.880679,
#  0.96027786,
#  314.89557,
#  381.5391,
#  271.65717,
#  1.0502418,
#  41.284313,
#  28.781527,
#  0.949498,
#  0.7834656,
#  1.1324193,
#  0.8943313,
#  53.45223,
#  1.2646666,
#  0.96958613,
#  1.0105706,
#  0.99035764,
#  0.98845,
#  1.05912,
#  1.194954,
#  16.061844,
#  1.5825323,
#  1.1287245,
#  0.31593856,
#  132.46724,
#  1.0008713,
#  12.654293,
#  1.0173693,
#  1.0238752,
#  13.9037285,
#  2.1688492,
#  74.72105,
#  14.246166,
#  5.927488,
#  1.1969031,
#  59.35419,
#  1.1059562,
#  0.9731209,
#  1.4397378,
#  1.2337434,
#  14.303022,
#  0.9972195,
#  6.027812,
#  59.694786,
#  0.75575215,
#  125.83044,
#  212.3402,
#  61.89833,
#  80.40158,
#  191.79411,
#  0.8831857,
#  350.71616,
#  0.7476079,
#  34.38479,
#  206.31693,
#  13.854499,
#  0.4518282,
#  17.08039,
#  234.65533,
#  205.94598,
#  33.718323,
#  16.78205,
#  0.91783595,
#  14.417049,
#  0.59485793,
#  27.211184,
#  0.99579364,
#  10.221538,
#  0.9314005,
#  9.570702,
#  0.72415686,
#  0.92201036,
#  389.1492,
#  381.77066,
#  385.54562,
#  392.9109,
#  378.97028,
#  109.7969,
#  281.97574,
#  13.083522,
#  1.0838273,
#  1.0750765,
#  28.912327,
#  1.2092048,
#  0.9517174,
#  237.76366,
#  0.95873487,
#  0.78418267,
#  1.101165,
#  0.991499,
#  0.956155,
#  1.0317895,
#  1.0334765,
#  0.9762368,
#  49.544624,
#  372.25345,
#  202.14326,
#  1.2632407,
#  1.0088309,
#  2.4617622,
#  1.7025282,
#  0.46076995,
#  1.461233,
#  1.4999049,
#  22.469105,
#  347.49243,
#  122.184975,
#  1.0532355,
#  0.6844657,
#  1.1141309,
#  0.91031766,
#  0.98787045,
#  1.1305635,
#  0.9029196,
#  0.09599414,
#  1.0396382,
#  25.293486,
#  2.228206,
#  51.033676,
#  202.4909,
#  1.603062,
#  8.066485,
#  -0.12323261,
#  1.4728234,
#  0.9542052,
#  9.906324,
#  15.791567,
#  9.833205,
#  337.72263,
#  1.973824,
#  1.069348,
#  10.005261,
#  20.054852,
#  1.1560051,
#  1.0946977,
#  8.772026,
#  7.123181,
#  0.45917022,
#  9.95929,
#  2.1168349,
#  0.95182455,
#  176.47783,
#  1.1199404,
#  1.0386665,
#  1.0875603,
#  1.2150232,
#  1.0262765,
#  0.7125167,
#  181.28883,
#  17.979742,
#  60.004906,
#  10.347361,
#  194.91289,
#  41.352955,
#  1.1414627,
#  9.023585,
#  119.64173,
#  1.0009232,
#  12.328461,
#  9.153429,
#  7.189844,
#  122.04429,
#  129.98643,
#  30.624643,
#  2.2819116,
#  23.549164,
#  3.2595649,
#  16.404514,
#  1.7448097,
#  0.7880193,
#  0.95569915,
#  23.401138,
#  0.8847347,
#  0.7517018,
#  1.0336142,
#  0.7496505,
#  13.034361,
#  0.82322973,
#  0.7974329,
#  202.56465,
#  109.06768,
#  30.497494,
#  0.6390886,
#  382.76694,
#  21.905563,
#  0.92126554,
#  341.14633,
#  1.0766536,
#  1.6807798,
#  6.1472735,
#  8.025072,
#  195.08101,
#  381.399,
#  363.02933,
#  280.75592,
#  195.00293,
#  274.4765,
#  360.29004,
#  163.14864,
#  198.66774,
#  371.76797,
#  369.40485,
#  375.12778,
#  0.9257554,
#  1.1790351,
#  0.56543857,
#  2.3346267,
#  1.3489914,
#  58.874023,
#  1.0021385,
#  1.1491184,
#  0.94928277,
#  1.0120846,
#  1.0475501,
#  0.95383996,
#  0.93647385,
#  0.96611893,
#  2.0914474,
#  0.81166744,
#  168.13466,
#  1.0819236,
#  1.0041518,
#  0.9857484,
#  1.1879269,
#  1.140467,
#  1.089027,
#  4.046196,
#  1.0329846,
#  0.8640443,
#  0.9729317,
#  0.74242127,
#  1.2223973,
#  7.1435504,
#  0.9201288,
#  27.146866,
#  1.1447372,
#  72.67348,
#  23.55803,
#  24.163692,
#  26.104588,
#  50.534374,
#  1.0079874,
#  25.98631,
#  24.418886,
#  0.90606254,
#  1.1395805,
#  0.96139526,
#  -2.5243766,
#  54.473152,
#  23.027685,
#  0.9960168,
#  17.412907,
#  43.98399,
#  1.0354,
#  19.155056,
#  1.0552659,
#  0.9017379,
#  6.9958367,
#  15.226158,
#  30.08288,
#  18.890785,
#  19.931807,
#  15.841636,
#  26.934223,
#  6.1310334,
#  0.681282,
#  0.7149309,
#  1.0931728,
#  26.34477,
#  15.343095,
#  59.616367,
#  0.97469085,
#  -5.199577,
#  16.957829,
#  1.1677948,
#  0.94451404,
#  18.680466,
#  0.83496207,
#  1.234266,
#  1.0977993,
#  1.0907048,
#  26.015041,
#  26.836988,
#  1.0552557,
#  32.070156,
#  14.001458,
#  19.978832,
#  30.433353,
#  12.790683,
#  15.117489,
#  23.247599,
#  10.0365715,
#  0.7859747,
#  10.05125,
#  49.903294,
#  4.0547633,
#  76.7404,
#  10.12427,
#  29.612076,
#  19.641043,
#  22.980114,
#  5.9369555,
#  15.8976965,
#  16.052486,
#  3.7389781,
#  27.262388,
#  0.9449756,
#  25.934093,
#  1.181573,
#  0.8247133,
#  12.644345,
#  19.148975,
#  23.2097,
#  10.986352,
#  10.12966,
#  1.0223538,
#  33.943794,
#  26.034513,
#  0.9270648,
#  0.7357905,
#  6.5171123,
#  50.26069,
#  26.868544,
#  8.757315,
#  1.0540681,
#  60.917294,
#  0.96466875,
#  1.052514,
#  0.70569295,
#  53.404358,
#  9.871428,
#  7.6674585,
#  110.10838,
#  25.722277,
#  172.31175,
#  218.61377,
#  36.03325,
#  5.8927226,
#  168.20839,
#  2.9122071,
#  197.25037,
#  3.0390356,
#  93.56819,
#  6.5094895,
#  9.65278,
#  38.77843,
#  204.5353,
#  2.0844822,
#  267.49017,
#  8.0238905,
#  7.715209,
#  0.037117783,
#  36.991966,
#  6.2556543,
#  0.69072795,
#  1.6295205,
#  9.5111,
#  10.027315,
#  199.84875,
#  6.7713733,
#  17.08849,
#  137.44644,
#  16.940207,
#  57.832203,
#  18.922943,
#  16.641624,
#  142.45972,
#  332.53897,
#  379.67395,
#  370.83908,
#  388.36035,
#  10.093373,
#  278.5688,
#  179.04305,
#  1.499068,
#  27.99527,
#  0.9366347,
#  1.0667444,
#  1.1444427,
#  5.9998593,
#  4.067744,
#  1.0197815,
#  128.46439,
#  75.87112,
#  1.1729586,
#  1.0935204,
#  1.0333151,
#  30.496796,
#  20.267288,
#  23.892464,
#  0.8145998,
#  32.421448,
#  6.1029296,
#  33.493526,
#  0.86250144,
#  7.9676332,
#  22.904417,
#  0.77158165,
#  1.5046784,
#  9.358607,
#  4.0521417,
#  24.896591,
#  5.9383264,
#  24.925558,
#  35.589108,
#  14.413257,
#  23.712267,
#  38.2109,
#  12.937781,
#  0.81642437,
#  383.24673,
#  7.802131,
#  32.895973,
#  1.6211712,
#  26.002672,
#  36.521862,
#  384.29898,
#  44.800266,
#  1.0373486,
#  0.87923133,
#  0.8180888,
#  1.0203626,
#  8.8623,
#  1.0478379,
#  0.8226591,
#  1.0723323,
#  376.49796,
#  378.8597,
#  -4.319493,
#  376.2912,
#  1.0821689,
#  0.71030843,
#  7.9876604,
#  20.340235,
#  1.1243818,
#  3.815685,
#  0.7901106,
#  0.67354286,
#  1.1387925,
#  1.0368401,
#  7.0595884,
#  0.91814613,
#  0.9735764,
#  0.8853467,
#  0.8783999,
#  0.7981013,
#  0.94211686,
#  1.2357391,
#  0.72656244,
#  0.9114034,
#  1.013543,
#  0.9253602,
#  0.9353412,
#  2.0031705,
#  0.86311376,
#  0.90938586,
#  1.0231534,
#  0.9642289,
#  1.1632494,
#  0.8968367,
#  301.63153,
#  8.831029,
#  0.9394422,
#  89.47182,
#  0.9146591,
#  0.8671644,
#  0.98543936,
#  20.578121,
#  0.96447587,
#  0.87668824,
#  128.21834,
#  0.95986116,
#  0.9586527,
#  0.983219,
#  1.0533346,
#  0.8519413,
#  0.9117756,
#  30.957014,
#  0.96514875,
#  0.9455191,
#  0.9718236,
#  0.8652438,
#  0.99663174,
#  0.96113133,
#  1.40046,
#  1.8298705,
#  190.5446,
#  0.49328503,
#  59.227795,
#  38.55543,
#  42.15935,
#  2.0131972,
#  43.131214,
#  51.896984,
#  15.915374,
#  56.04249,
#  0.8470391,
#  6.628394,
#  0.9452156,
#  1.016965,
#  1.4270608,
#  0.8574557,
#  0.82092094,
#  1.1147127,
#  1.133952,
#  273.5081,
#  0.9801075,
#  277.83075,
#  182.39058,
#  1.0566844,
#  0.9906848,
#  192.21089,
#  1.0625316,
#  0.9832907,
#  0.9935867,
#  1.009589,
#  132.30618,
#  1.0629828,
#  15.888926,
#  1.0083097,
#  1.2279576,
#  1.3303318,
#  280.00174,
#  0.37723213,
#  1.0612928,
#  0.84318465,
#  320.6664,
#  1.5639685,
#  1.0696952,
#  1.4627678,
#  0.33424482,
#  372.8784,
#  168.2008,
#  369.59106,
#  273.21243,
#  376.10217,
#  11.329918,
#  0.92721885,
#  1.144149,
#  33.34138,
#  149.53595,
#  68.229774,
#  151.16788,
#  378.8956,
#  66.1792,
#  1.0385042,
#  9.434512,
#  8.042124,
#  1.2038622,
#  104.73763,
#  122.91093,
#  1.1370999,
#  0.7092135,
#  1.1305046,
#  1.0020651,
#  1.0770609,
#  0.45059425,
#  1.0420841,
#  48.91485,
#  0.9975863,
#  0.8481919,
#  0.8955326,
#  0.9933468,
#  1.0924358,
#  44.844597,
#  1.0682993,
#  118.29087,
#  18.046074,
#  0.87284833,
#  212.12167,
#  1.1281902,
#  53.93434,
#  1.0710078,
#  41.893536,
#  3.0543234,
#  0.95715576,
#  1.0515743,
#  1.1086863,
#  0.85303354,
#  34.292725,
#  0.95535636,
#  0.9691419,
#  0.989344,
#  1.0170131,
#  122.39901,
#  131.65189,
#  0.8535267,
#  0.87242246,
#  1.3052323,
#  0.8522344,
#  1.0322484,
#  0.98337764,
#  3.1337318,
#  0.8808553,
#  9.928388,
#  10.86319,
#  121.89659,
#  121.51069,
#  209.05469,
#  10.471795,
#  0.07775956,
#  1.1494617,
#  0.874504,
#  31.040842,
#  203.34789,
#  105.37235,
#  0.7805806,
#  11.692276,
#  4.867681,
#  1.3043137,
#  1.1727024,
#  0.9218291,
#  299.19626,
#  1.0717055,
#  25.049551,
#  0.9519374,
#  39.33072,
#  40.275177,
#  8.3243885,
#  17.247744,
#  17.539228,
#  41.229027,
#  13.407692,
#  0.9930633,
#  1.0073171,
#  21.704527,
#  214.3415,
#  203.75352,
#  111.61229,
#  104.27703,
#  126.26895,
#  168.57881,
#  216.62392,
#  88.73774,
#  113.25162,
#  107.679016,
#  177.79245,
#  84.32047,
#  157.76079,
#  331.23746,
#  198.56737,
#  217.54907,
#  166.47449,
#  296.1739,
#  108.564804,
#  141.70451,
#  59.628727,
#  140.73228,
#  219.28032,
#  180.2253,
#  2.1204493,
#  12.614159,
#  193.14679,
#  15.077862,
#  0.93797123,
#  1.0164028,
#  63.219006,
#  0.7690747,
#  29.071182,
#  170.98143,
#  1.0059217,
#  1.0982221,
#  0.54744524,
#  29.222792,
#  26.881447,
#  27.436316,
#  71.554245,
#  222.96596,
#  0.5368392,
#  197.85927,
#  2.54164,
#  60.850647,
#  6.781187,
#  1.3900303,
#  10.410778,
#  41.967644,
#  1.0439746,
#  4.97785,
#  1.1258286,
#  1.0933172,
#  0.33430675,
#  -1.165254,
#  7.055588,
#  28.926464,
#  36.30014,
#  204.27187,
#  274.29617,
#  205.80362,
#  53.307793,
#  42.113434,
#  291.22653,
#  283.56866,
#  293.60657,
#  274.5344,
#  79.188446,
#  87.490295,
#  220.22446,
#  244.46684,
#  224.45694,
#  59.172638,
#  279.83304,
#  152.95256,
#  1.018232,
#  0.81076175,
#  1.3367101,
#  0.88384116,
#  1.7128195,
#  0.87120265,
#  54.341522,
#  45.38024,
#  3.182653,
#  1.141701,
#  1.2607287,
#  6.1282563,
#  1.0901439,
#  1.0858634,
#  1.2113396,
#  0.85709965,
#  34.62668,
#  3.1571121,
#  1.0111845,
#  1.2122537,
#  7.409445,
#  9.982315,
#  1.2306113,
#  1.336755,
#  17.760292,
#  57.175632,
#  1.0810426,
#  1.1680853,
#  1.0630214,
#  5.5115085,
#  186.99855,
#  91.87051,
#  56.339954,
#  14.072615,
#  64.0247,
#  21.939096,
#  21.140461,
#  1.0266176,
#  0.9357185,
#  0.8254606,
#  0.8325051,
#  0.9421152,
#  0.83747137,
#  0.7994266,
#  35.24865,
#  1.0217226,
#  0.8573702,
#  1.0906671,
#  1.373448,
#  9.693503,
#  1.9107951,
#  1.0955166,
#  11.367391,
#  1.4237449,
#  1.0197186,
#  1.347167,
#  177.74115,
#  1.0490795,
#  0.8895695,
#  1.2799314,
#  0.76502514,
#  2.677527,
#  1.1541297,
#  0.45492244,
#  1.3690401,
#  0.7515921,
#  0.78428054,
#  0.8530854,
#  0.91374373,
#  1.0327569,
#  9.859144,
#  1.0123699,
#  2.0352678,
#  36.687607,
#  82.98895,
#  0.9856789,
#  1.2181659,
#  0.42781356,
#  1.2724341,
#  1.1338801,
#  0.80138135,
#  1.552923,
#  0.24427113,
#  74.71364,
#  203.22408,
#  53.3003,
#  79.89241,
#  285.87448,
#  -4.685476,
#  0.4760095,
#  156.59383,
#  0.3803156,
#  2.9721987,
#  1.4076415,
#  118.552055,
#  3.0203552,
#  246.45593,
#  239.90485,
#  265.87735,
#  261.41617,
#  259.17624,
#  30.751076,
#  0.82343423,
#  65.40488,
#  89.25328,
#  109.15545,
#  73.81637,
#  0.96650416,
#  1.3737458,
#  0.97942626,
#  1.0793651,
#  0.93700814,
#  1.05313,
#  1.2668451,
#  1.0265425,
#  0.88480204,
#  0.948337,
#  0.7694054,
#  1.120147,
#  1.0946274,
#  1.1134859,
#  1.0283846,
#  1.209746,
#  0.71791613,
#  0.80991036,
#  -0.57868695,
#  0.36332387,
#  1.0465138,
#  0.6590424,
#  1.0258112,
#  1.0949186,
#  0.93836594,
#  0.96121585,
#  1.0396256,
#  0.8532355,
#  0.52705526,
#  0.86132306,
#  0.880658,
#  1.0806006,
#  0.7427076,
#  0.89714223,
#  1.3027773,
#  0.84203625,
#  214.61252,
#  265.64215,
#  212.60022,
#  228.4612,
#  288.05478,
#  61.809566,
#  215.65878,
#  197.15768,
#  10.175985,
#  293.89236,
#  56.067795,
#  14.72929,
#  13.99665,
#  0.9825246,
#  12.829679,
#  1.0159636,
#  29.186356,
#  31.430735,
#  8.129833,
#  34.22834,
#  44.467426,
#  16.12494,
#  33.974503,
#  1.2777618,
#  3.1107173,
#  1.0484655,
#  1.4635955,
#  1.3748007,
#  202.83223,
#  1.2016208,
#  1.3957775,
#  193.89601,
#  0.83075535,
#  0.9194322,
#  1.0891228,
#  1.4009635,
#  1.0807577,
#  1.4952441,
#  1.4382452,
#  1.1772625,
#  13.908668,
#  27.091423,
#  1.003185,
#  0.8914503,
#  0.9083082,
#  -0.17430238,
#  34.44013,
#  1.0679464,
#  0.9646299,
#  1.1382195,
#  0.78535926,
#  0.96405137,
#  5.8254933,
#  7.5464797,
#  1.1022434,
#  1.1702836,
#  1.1799717,
#  25.047302,
#  14.838411,
#  25.111189,
#  1.0435735,
#  1.0512136,
#  1.5101323,
#  53.143158,
#  20.20761,
#  1.2170554,
#  2.1394253,
#  0.9974968,
#  24.92278,
#  1.0530412,
#  1.1370249,
#  1.2526225,
#  1.7052948,
#  0.95796794,
#  0.963191,
#  45.038162,
#  ...]

# %%
submission["hold_d"] = np.round(result)

# %%
submission
# Out:
#       submit_id  hold_d
# 0      IDX00001    32.0
# 1      IDX00002    90.0
# 2      IDX00003    28.0
# 3      IDX00004    60.0
# 4      IDX00005     1.0
# ...         ...     ...
# 70591  IDX70592     1.0
# 70592  IDX70593    16.0
# 70593  IDX70594   240.0
# 70594  IDX70595     1.0
# 70595  IDX70596     1.0
#
# [70596 rows x 2 columns]

# %%
submission.to_csv("./result/xgboost(iem_cd_target_encoding lib with hist_d volume past_d(mean) ivs past_d & scaling).csv", index = False)

# %%
train_df.columns
# Out:
# Index(['hold_d', 'sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd',
#        'cus_aet_stn_cd', 'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'hist_d', 'volume', 'iem_cd_te',
#        'act_past_d_mean', 'ivs_past_d_mean'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['sex_dit_cd', 'cus_age_stn_cd', 'ivs_icn_cd', 'cus_aet_stn_cd',
#        'mrz_pdt_tp_sgm_cd', 'lsg_sgm_cd', 'tco_cus_grd_cd',
#        'tot_ivs_te_sgm_cd', 'mrz_btp_dit_cd', 'iem_krl_nm', 'btp_cfc_cd',
#        'mkt_pr_tal_scl_tp_cd', 'stk_dit_cd', 'hist_d', 'volume', 'iem_cd_te',
#        'act_past_d_mean', 'ivs_past_d_mean'],
#       dtype='object')

# %%
test_df
# Out:
#        sex_dit_cd  cus_age_stn_cd  ivs_icn_cd  cus_aet_stn_cd  \
# 0               1               9           3               2
# 1               1               9           3               2
# 2               1               9           3               2
# 3               1               9           3               2
# 4               1               9           3               2
# ...           ...             ...         ...             ...
# 70591           1               6           0               5
# 70592           1               6           0               5
# 70593           1               4           4               2
# 70594           1               4           4               2
# 70595           1               4           4               2
#
#        mrz_pdt_tp_sgm_cd  lsg_sgm_cd  tco_cus_grd_cd  tot_ivs_te_sgm_cd  \
# 0                      2           9               5                  5
# 1                      2           9               5                  5
# 2                      2           9               5                  5
# 3                      2           9               5                  5
# 4                      2           9               5                  5
# ...                  ...         ...             ...                ...
# 70591                  2           5               3                  5
# 70592                  2           5               3                  5
# 70593                  2           3               4                  3
# 70594                  2           3               4                  3
# 70595                  2           3               4                  3
#
#        mrz_btp_dit_cd  iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  \
# 0                   8         418           4                     1
# 1                   8        2230          10                     3
# 2                   8        1515          13                     2
# 3                   8        2681          13                     3
# 4                   8        2450          13                     1
# ...               ...         ...         ...                   ...
# 70591               2        1369           2                     1
# 70592               2         444           2                    99
# 70593               8        1280          14                     3
# 70594               8        2373           8                     2
# 70595               8        2371           8                     2
#
#        stk_dit_cd    hist_d    volume  iem_cd_te  act_past_d_mean  \
# 0               1  0.244175  0.039721   0.073982         0.298371
# 1              99  1.361902 -0.341544   0.148961         1.490101
# 2              99  0.158196 -0.376782   0.114638         0.212811
# 3              99  0.753908 -0.238048  -0.401725         0.842289
# 4               2 -0.640180 -0.045461  -0.805707        -0.612233
# ...           ...       ...       ...        ...              ...
# 70591           1 -0.554201 -0.393597   0.140479        -0.596954
# 70592          99 -0.062893 -0.399973   2.143246        -0.007201
# 70593          99  4.573831 -0.206895  -1.394850         4.900282
# 70594          99 -0.627897 -0.408747   0.139291        -0.633623
# 70595           1 -0.670887 -0.394845  -0.508662        -0.652976
#
#        ivs_past_d_mean
# 0             0.083664
# 1             0.084534
# 2            -0.107178
# 3            -0.005340
# 4            -0.266645
# ...                ...
# 70591        -0.703553
# 70592         2.076436
# 70593         9.795720
# 70594        -0.200188
# 70595        -0.215105
#
# [70596 rows x 18 columns]
